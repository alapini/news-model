# %%
import logging
from collections import defaultdict
from functools import lru_cache
from pathlib import Path
from numba import jit
import numpy as np

import spacy
from bson.objectid import ObjectId
from gensim.models import KeyedVectors
from nltk.corpus import stopwords
from pymongo import MongoClient
from tqdm import tqdm

logging.basicConfig(format='%(asctime)s : %(message)s', level=logging.INFO)
_info = logging.info

client = MongoClient('mongodb://localhost:27017')
db = client.twitter_news
nlp = spacy.load('en_core_web_sm', tagger=False, entity=False, matcher=False)


def hashtag_pipe(doc):
    merged_hashtag = False
    while True:
        for token_index, token in enumerate(doc):
            if token.text == '#':
                if token.head is not None:
                    start_index = token.idx
                    end_index = start_index + len(token.head.text) + 1
                    if doc.merge(start_index, end_index) is not None:
                        merged_hashtag = True
                        break
        if not merged_hashtag:
            break
        merged_hashtag = False
    return doc


nlp.add_pipe(hashtag_pipe)


total_events = 3


@lru_cache(maxsize=total_events)
def get_representatives(event_id):
    _info("getting representatives")
    representatives = db.representatives.find({'event': ObjectId(event_id)})
    return list(representatives)


@lru_cache(maxsize=total_events)
def get_topics(event_id):
    _info("getting topics")
    topics = list(db.topics.find({'event': ObjectId(event_id)}))
    comodin = None
    for t in topics:
        if t['topic_name'] == "Non relevant":
            comodin = t
            topics.remove(t)
            break
    return topics, comodin


@lru_cache(maxsize=1)
def get_events():
    _info("getting events")
    events = db.events.find()
    return list(events)


@lru_cache(maxsize=1)
def get_tweets(a=None):
    _info('getting all tweets')
    all_tweets = db.tweets.find()
    return list(all_tweets)


@lru_cache(maxsize=3)
def get_vectors(path):
    _info(f"loading fasttext vectors from {path}")
    word_vectors = KeyedVectors.load_word2vec_format(path)
    return word_vectors


@lru_cache(maxsize=2**30)
def sim(tokens_a, tokens_b):
    return ft_comp.n_similarity(tokens_a, tokens_b)


def mmr(docs, query, l):
    def mmr_score(tweet):
        return l * sim(docs[tweet], query) - \
               (1 - l) * max([sim(docs[tweet], docs[y]) for y in set(selected) - {tweet}] or [0])

    L = np.array([[l, 0], [0, l - 1]])

    def score(tweet):
        s1 = sim(docs[tweet], query)
        s2 = np.max(np.array([sim(docs[tweet], docs[y]) for y in set(selected) - {tweet}] or [0]))

        return L.dot(np.array([s1, s2])).sum()

    selected = set()
    while selected != set(docs):
        remaining = list(set(docs) - selected)
        next_selected = max(remaining, key=mmr_score)
        # next_selected = remaining[np.argmax([score(t) for t in remaining])]

        # next_selected = None
        # max_score = 0
        #
        # for _t in remaining:
        #     score = l * sim(docs[_t], query) - \
        #             (1 - l) * max([sim(docs[_t], docs[y]) for y in set(selected) - {_t}] or [0])
        #     if score > max_score:
        #         max_score = score
        #         next_selected = _t

        selected.add(next_selected)
        yield next_selected, ' '.join(list(docs[next_selected]))


@lru_cache(maxsize=total_events)
def process_tweets(event_id):
    all_tweets = get_tweets()
    representatives = get_representatives(event_id)

    _info("processing tweets")

    # rep_tweet: repr_id => tweet
    rep_tweet = dict()
    for t in tqdm(all_tweets):
        rep_tweet[t['representative']] = t

    # repr_ids: {repr_id} // this event
    repr_ids = set([r['_id'] for r in representatives])

    # tweets_this_event: [tweet]
    tweets_this_event = [t for r, t in rep_tweet.items() if r in repr_ids]

    tweets_tokens = dict()
    all_tokens = set()
    for tweet, doc in tqdm(zip(tweets_this_event, nlp.pipe([_t['text'] for _t in tweets_this_event],
                                                           n_threads=8,
                                                           batch_size=1024)),
                           total=len(tweets_this_event)):

        tokens = frozenset([token.lower_
                            for token in doc
                            if token.lower_ not in stopwords.words('english') and token.lower_ in ft_comp])

        if tokens and tokens not in all_tokens:
            tweets_tokens[str(tweet['_id'])] = tokens
            all_tokens.add(tokens)

    return tweets_tokens


path = Path('/home/mquezada/anchor-text-twitter/data/ft_alltweets_model.vec')
ft_comp = get_vectors(path.as_posix())
events = get_events()

topics = list()
for event in events:
    topics.append([frozenset([t.lower()
                              for t in topic['topic_name'].split()])
                   for topic in get_topics(event['_id'])[0]])
# Out:
# 2018-06-28 14:44:18,250 : loading fasttext vectors from /home/mquezada/anchor-text-twitter/data/ft_alltweets_model.vec
# 2018-06-28 14:44:18,251 : loading projection weights from /home/mquezada/anchor-text-twitter/data/ft_alltweets_model.vec
# 2018-06-28 14:45:18,491 : loaded (1076139, 100) matrix from /home/mquezada/anchor-text-twitter/data/ft_alltweets_model.vec
# 2018-06-28 14:45:18,491 : getting events
# 2018-06-28 14:45:18,493 : getting topics
# 2018-06-28 14:45:18,494 : getting topics
# 2018-06-28 14:45:18,495 : getting topics

# %%
event = events[0]
tweets_tokens = process_tweets(event['_id'])

topics_this_event, _ = get_topics(event['_id'])
topic = topics_this_event[0]
topic_tokens = frozenset([t.lower() for t in topic['topic_name'].split()])
topic_tokens
# Out:
# frozenset({'bomb', 'car', 'explodes'})

# %%
event
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-cc102de9059f> in <module>()
# ----> 1 event
#
# NameError: name 'event' is not defined

# %%
sim.cache_clear()

# %%
# %%time

for i, obj in enumerate(mmr(tweets_tokens, topic_tokens, 0.6)):
    print(obj)
    if i == 10:
        break
# Out:
# ('5b17172ada870923dcb095b6', 'park bomb explodes corinthia car')
# ('5b17172ada870923dcb09245', 'hotel libya outside bomb capital explodes witnesses car')
# ('5b171729da870923dcb08977', 'hotel via outside bomb explodes tripoli car')
# ('5b171729da870923dcb08b23', 'hotel outside bomb explodes tripoli car')
# ('5b171729da870923dcb08894', '#tripoli hotel outside bomb explodes east car middle')
# ('5b171729da870923dcb08de7', '#world hotel outside bomb explodes tripoli car')
# ('5b17172ada870923dcb09414', 'sale hotel outside bomb explodes tripoli car #news')
# ('5b171729da870923dcb08e25', 'hotel #civil_vision outside bomb explodes tripoli car')
# ('5b17172ada870923dcb09379', 'post hotel outside bomb explodes car tripoli new')
# ('5b171729da870923dcb08ac5', 'hotel 3 outside bomb car kills')
# ('5b171729da870923dcb08c2c', 'latest hotel outside bomb explodes tripoli car #news')
# CPU times: user 4.75 s, sys: 3.32 ms, total: 4.76 s
# Wall time: 4.75 s

# %%
# %%time

from scipy.linalg import norm
from numba import jit
import random

event = events[1]
tweets_tokens = process_tweets(event['_id'])

lambda_ = 0.6
_1_lambda_ = 1 - lambda_

n_docs = len(tweets_tokens)
tweet_vectors = np.array([np.mean([ft_comp[token] for token in tokens], axis=0) for _, tokens in tweets_tokens.items()])
norm_vectors = tweet_vectors / norm(tweet_vectors)

@lru_cache(maxsize=2**20)
@jit
def sim_c(doc_x, doc_y):
    return norm_vectors[doc_x].dot(norm_vectors[doc_y].T)

topics_this_event, _ = get_topics(event['_id'])

for topic in topics_this_event:  
    query = topic.get('keywords')
    
    if not query:
        continue

    query = np.mean([ft_comp[token] for token in query if token in ft_comp], axis=0)
    doc_q_sim = (norm_vectors).dot(query) * lambda_

    @jit
    def score(doc_x, selected):
        max_sim = 0
        if selected - {doc_x}:
            for doc_y in selected - {doc_x}:
                sim = sim_c(doc_x, doc_y)
                if sim > max_sim:
                    max_sim = sim

        return doc_q_sim[doc_x] - _1_lambda_ * max_sim

    def mmr2(docs, lim=500):
        selected = set()

        for i in range(lim):
            remaining = set(docs) - selected

            max_score = 0
            next_selected = None
            for r in remaining:
                sc = score(r, frozenset(selected))
                if sc > max_score:
                    max_score = sc
                    next_selected = r

            selected.add(next_selected)
            yield next_selected
            

    #sample = random.sample(list(tweets_tokens), len(tweets_tokens) // 2)
    sample = list(tweets_tokens)
    export_dir = Path('/home/mquezada/tweet_topics/')
    print(topic['topic_name'])

    f_name = f'event_{event["_id"]}-topic_{topic["_id"]}-tweet_ids_sorted_mmr.txt'
    with (export_dir / Path(f_name)).open('w') as f:
        for i in tqdm(mmr2(range(len(sample)))):
            f.write(f'{sample[i]}\n')
# Out:
# 2018-06-29 09:42:10,496 : getting representatives
# 2018-06-29 09:42:10,732 : processing tweets
# 100%|██████████| 642251/642251 [00:00<00:00, 1305070.46it/s]
# 100%|██████████| 82626/82626 [04:34<00:00, 301.35it/s]
# 0it [00:00, ?it/s]
# Oscar Pistorius apologizes
# 500it [3:35:49, 25.90s/it]
# 0it [00:00, ?it/s]
# Oscar Pistorius vomits on court
# 296it [1:24:19, 17.09s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed exec> in <module>()
#
# ~/anaconda3/envs/news-model/lib/python3.6/site-packages/tqdm/_tqdm.py in __iter__(self)
#     928 """, fp_write=getattr(self.fp, 'write', sys.stderr.write))
#     929
# --> 930             for obj in iterable:
#     931                 yield obj
#     932                 # Update and possibly print the progressbar.
#
# <timed exec> in mmr2(docs, lim)
#
# KeyboardInterrupt:

# %%
sample
# Out:
# ['5b1717aada870923dcbdb0d3',
#  '5b171791da870923dcbaef75',
#  '5b17179cda870923dcbc39bf',
#  '5b17176bda870923dcb60a2c',
#  '5b171777da870923dcb7ad83',
#  '5b17177ada870923dcb8067f',
#  '5b1717a8da870923dcbd75e0',
#  '5b171778da870923dcb7b500',
#  '5b17179cda870923dcbc3ccd',
#  '5b171772da870923dcb6fac3',
#  '5b1717a6da870923dcbd522d',
#  '5b17177bda870923dcb81298',
#  '5b1717aada870923dcbdac05',
#  '5b17179eda870923dcbc6a72',
#  '5b17176eda870923dcb6861d',
#  '5b1717a8da870923dcbd7bb4',
#  '5b17176ada870923dcb5f90e',
#  '5b17178bda870923dcba3add',
#  '5b171764da870923dcb51dcc',
#  '5b171770da870923dcb6b9e6',
#  '5b17177bda870923dcb8188b',
#  '5b171781da870923dcb8d4ac',
#  '5b171771da870923dcb6d1d9',
#  '5b171775da870923dcb73f0c',
#  '5b171787da870923dcb9bf27',
#  '5b171796da870923dcbb8831',
#  '5b17177dda870923dcb8480b',
#  '5b171764da870923dcb51f92',
#  '5b171765da870923dcb5306e',
#  '5b171793da870923dcbb26da',
frozenset({'7.7',
#             'buildings',
#             'capital',
#             'collapse',
#             'nepal',
#             'quake',
#             'witnesses'}),
#  '5b17175bda870923dcb3e068': frozenset({'air',
#             'bad',
#             'buildings',
#             'comming',
#             'dust',
#             'felt',
#             'many',
#             'nepal',
#             'news',
#             'pall',
#             'region',
#             'reports',
#             'say',
#             'still',
#             'tremors'}),
#  '5b17175bda870923dcb3e094': frozenset({'#earthquake',
#             '#nepal',
#             'buildings',
#             'damaged',
#             'houses',
#             'public',
#             'several'}),
#  '5b17175bda870923dcb3e109': frozenset({'air',
#             'badly',
#             'breaking',
#             'buildings',
#             'dust',
#             'felt',
#             'hit',
#             'many',
#             'nepal',
#             'pall',
#             'region',
#             'still',
#             'tremors',
#             '|'}),
#  '5b17175bda870923dcb3e48e': frozenset({'buildings',
#             'cnn',
#             'earthquake',
#             'ibn',
#             'major',
#             'nepal',
#             'network',
#             'reports',
#             'roads',
#             'sister'}),
#  '5b17175bda870923dcb3e490': frozenset({'bless',
#             'buildings',
#             'collapsed',
#             'krishna',
#             'like',
#             'looks',
#             'lot',
#             'nepal',
#             'omg',
#             'sri'}),
#  '5b17175bda870923dcb3e496': frozenset({'#quake',
#             '-witnesses',
#             '7.7',
#             'buildings',
#             'capital',
#             'collapse',
#             'nepal'}),
#  '5b17175bda870923dcb3e4a6': frozenset({'#pr9anya',
#             '7.7',
#             'buildings',
#             'capital',
#             'collapse',
#             'nepal',
#             'quake',
#             'witnesses'}),
#  '5b17175bda870923dcb3e4a8': frozenset({'#katmandu',
#             '#nepal',
#             '#pakistan',
#             "'s",
#             '7.4',
#             'buildings',
#             'capital',
#             'damage',
#             'earthquake',
#             'hit',
#             'magnitude',
#             'reported',
#             'richter',
#             'scale',
#             'widespread'}),
#  '5b17175bda870923dcb3e565': frozenset({'#kathmandu',
#             '#nepal',
#             '7.7',
#             'buildings',
#             'capital',
#             'collapsed',
#             'earthquake',
#             'hits',
#             'magnitude',
#             'nepali',
#             'reuters',
#             'update'}),
#  '5b17175bda870923dcb3e57b': frozenset({'7.7',
#             'buildings',
#             'collapse',
#             'nepal',
#             'quake',
#             'witnesses'}),
#  '5b17175bda870923dcb3e57d': frozenset({'buildings',
#             'capital',
#             'collapse',
#             'nepal',
#             'quake',
#             'witnesses'}),
#  '5b17175bda870923dcb3e5b1': frozenset({'buildings',
#             'cnn',
#             'cnnbrk',
#             'earthquake',
#             'ibn',
#             'major',
#             'nepal',
#             'network',
#             'reports',
#             'roads',
#             'sister'}),
#  '5b17175bda870923dcb3e650': frozenset({'#earthquake',
#             'bad',
#             'buildings',
#             'continuing',
#             'friends',
#             'kathmandu',
#             'nepal',
#             'really',
#             'sounds',
#             'tell',
#             'terrible',
#             'tremors'}),
#  '5b17175bda870923dcb3e656': frozenset({'#earthquake',
#             "'re",
#             "'s",
#             'buildings',
#             'capital',
#             'collapsed',
#             'earthquake',
#             'following',
#             'hearing',
#             'kathmandu',
#             'major',
#             'nepal',
#             'reports',
#             'several',
#             'skynews'}),
#  '5b17175bda870923dcb3e688': frozenset({'7.5',
#             'buildings',
#             'collapse',
#             'earthquake',
#             'magnitude',
#             'nepal'}),
#  '5b17175bda870923dcb3e68a': frozenset({'breaking',
#             'buildings',
#             'cnn',
#             'major',
#             'nepal',
#             'news',
#             'roads'}),
#  '5b17175bda870923dcb3e68c': frozenset({'#terrorism',
#             '7.7',
#             'buildings',
#             'capital',
#             'collapse',
#             'nepal',
#             'quake',
#             'witnesses'}),
#  '5b17175bda870923dcb3e690': frozenset({'#earthquake',
#             'brick',
#             'buildings',
#             'done',
#             'kathmandu',
#             'nepal',
#             'old',
#             'red',
#             'well'}),
#  '5b17175bda870923dcb3e693': frozenset({'#nepal',
#             '7.7',
#             'due',
#             'earthquake',
#             'fear',
#             'magnitude',
#             'open',
#             'people',
#             'space'}),
#  '5b17175bda870923dcb3e695': frozenset({'buildings',
#             'earthquake',
#             'major',
#             'nepal',
#             'roads'}),
#  '5b17175bda870923dcb3e6ac': frozenset({'air',
#             'badly',
#             'breaking',
#             'buildings',
#             'dust',
#             'earthquake',
#             'hit',
#             'many',
#             'nepal',
#             'pall'}),
#  '5b17175bda870923dcb3e6ae': frozenset({'7.7',
#             'buildings',
#             'collapse',
#             'nepal',
#             'quake',
#             'witnesses',
#             '|'}),
#  '5b17175bda870923dcb3e6b2': frozenset({'buildings',
#             'capital',
#             'destroys',
#             'earthquake',
#             'nepal'}),
#  '5b17175bda870923dcb3e6b4': frozenset({'#ysealireusablebag',
#             '7.7-magnitude',
#             'buildings',
#             'collapsed',
#             'earthquake',
#             'nepal',
#             'reported',
#             'strikes'}),
#  '5b17175bda870923dcb3e716': frozenset({'#earthquake',
#             '#nepal',
#             'asian',
#             'breaking',
#             'buildings',
#             'capital',
#             'country',
#             'hits',
#             'reporters',
#             'said',
#             'shaking',
#             'strong',
#             'xinhua'}),
#  '5b17175bda870923dcb3e718': frozenset({'7.7',
#             '80',
#             'buildings',
#             'collapses',
#             'earthquake',
#             'k',
#             'magnitude',
#             'measuring',
#             'nepal',
#             'struck'}),
#  '5b17175bda870923dcb3e71a': frozenset({"'s",
#             '7.7-magnitude',
#             'buildings',
#             'capital',
#             'collapsed',
#             'earthquake',
#             'itvnews',
#             'kathmandu',
#             'nepal',
#             'say',
#             'witnesses'}),
#  '5b17175bda870923dcb3e71e': frozenset({'7.7',
#             'buildings',
#             'capital',
#             'collapse',
#             'etribune',
#             'nepal',
#             'quake',
#             'sports',
#             'witnesses',
#             '|'}),
#  '5b17175bda870923dcb3e722': frozenset({'7.5',
#             'astaghfirullaah',
#             'buildings',
#             'collapse',
#             'earthquake',
#             'magnitude',
#             'nepal'}),
#  '5b17175bda870923dcb3e724': frozenset({'almighty',
#             'buildings',
#             'earthquake',
#             'major',
#             'may',
#             'nepal',
#             'prayers',
#             'roads',
#             'show'}),
#  '5b17175bda870923dcb3e726': frozenset({'7.7',
#             'buildings',
#             'capital',
#             'collapse',
#             'earthquake',
#             'measuring',
#             'nepal',
#             'quake',
#             'reuters',
#             'witnesses'}),
#  '5b17175bda870923dcb3e745': frozenset({'7.7-magnitude',
#             'buildings',
#             'collapsed',
#             'earthquake',
#             'nepal',
#             'reported',
#             'strikes'}),
#  '5b17175bda870923dcb3e747': frozenset({'buildings',
#             'cnn',
#             'cnn-',
#             'earthquake',
#             'major',
#             'nepal',
#             'network',
#             'roads',
#             'sister'}),
#  '5b17175bda870923dcb3e751': frozenset({'buildings',
#             'drill',
#             'earthquake',
#             'enable',
#             'inside',
#             'institutions',
#             'nepal',
#             'people',
#             'safety',
#             'severe'}),
#  '5b17175bda870923dcb3e753': frozenset({'7.7',
#             'buildings',
#             'capital',
#             'collapse',
#             'nepal',
#             'quake',
#             'reuters',
#             'uk',
#             'witnesses'}),
#  '5b17175bda870923dcb3e755': frozenset({'buildings',
#             'cnn',
#             'cnnbrk',
#             'earthquake',
#             'ibn',
#             'major',
#             'nepal',
#             'network',
#             'reports',
#             'roads',
#             'rt',
#             'sister'}),
#  '5b17175bda870923dcb3e75b': frozenset({'#nepalquake',
#             '7.5',
#             'buildings',
#             'cnn',
#             'damaged',
#             'earthquake',
#             'ibn',
#             'kathmandu',
#             'nepal',
#             'pray'}),
#  '5b17175bda870923dcb3e75d': frozenset({'#nepal',
#             'buildings',
#             'collapsed',
#             'damage',
#             'injuries',
#             'kathmandu',
#             'official',
#             'quake',
#             'reportedly',
#             'reports'}),
#  '5b17175bda870923dcb3e761': frozenset({'7.7',
#             'breaking',
#             'buildings',
#             'capital',
#             'collapse',
#             'nepal',
#             'news',
#             'quake',
#             'witnesses'}),
#  '5b17175bda870923dcb3e79c': frozenset({'7.7',
#             'buildings',
#             'capital',
#             'destroys',
#             'earthquake',
#             'knocked',
#             'magnitude',
#             'nepal'}),
#  '5b17175bda870923dcb3e79e': frozenset({'#staysafe',
#             'buildings',
#             'earthquake',
#             'epicenter',
#             'get',
#             'nepal'}),
#  '5b17175bda870923dcb3e7d8': frozenset({'#nepal',
#             '#quake',
#             "'s",
#             'buildings',
#             'capital',
#             'collapsed',
#             'coming',
#             'eyewitness',
#             'kathmandu',
#             'many',
#             'numerous',
#             'reports'}),
#  '5b17175bda870923dcb3e7dd': frozenset({'#earthquake',
#             'buildings',
#             'construction',
#             'could',
#             'death',
#             'nepal',
#             'old',
#             'poor',
#             'traps',
#             'turn',
#             'w/',
#             'worn'}),
#  '5b17175bda870923dcb3e7e4': frozenset({"'s",
#             '7.5',
#             'buildings',
#             'capitol',
#             'collapsed',
#             'following',
#             'kathmandu',
#             'major',
#             'nepal',
#             'quake'}),
#  '5b17175bda870923dcb3e7e7': frozenset({'#earthquake',
#             '#nepal',
#             'also',
#             'buildings',
#             'damaged',
#             'several'}),
#  '5b17175bda870923dcb3e83c': frozenset({'7.7-magnitude',
#             'buildings',
#             'capital',
#             'collapsed',
#             'earthquake',
#             'hit',
#             'nepals',
#             'reported'}),
#  '5b17175bda870923dcb3e842': frozenset({'#khatmandu',
#             'buildings',
#             'collapsed',
#             'earthquake',
#             'hit',
#             'nepal',
#             'scores',
#             'worst'}),
#  '5b17175bda870923dcb3e848': frozenset({'#earthquake',
#             '7.5',
#             'buildings',
#             'damaged',
#             'hits',
#             'measuring',
#             'nepal',
#             'several'}),
#  '5b17175bda870923dcb3e84a': frozenset({'#train',
#             '7.7',
#             'buildings',
#             'capital',
#             'collapse',
#             'nepal',
#             'quake',
#             'witnesses'}),
#  '5b17175bda870923dcb3e852': frozenset({'7.5-magnitude',
#             'buildings',
#             'delhi',
#             'earthquake',
#             'evacuated',
#             'even',
#             'felt',
#             'hits',
#             'nepal',
#             'new',
#             'tremors'}),
#  '5b17175bda870923dcb3e854': frozenset({'#pakistan',
#             '7.7',
#             'buildings',
#             'capital',
#             'collapse',
#             'nepal',
#             'quake',
#             'tv',
#             'witnesses'}),
#  '5b17175bda870923dcb3e85f': frozenset({'7.7-magnitude',
#             'buildings',
#             'capital',
#             'collapse',
#             'nepal',
#             'quake'}),
#  '5b17175bda870923dcb3e863': frozenset({'bangladesh',
#             'buildings',
#             'damaged',
#             'heard',
#             'many',
#             'nepal'}),
#  '5b17175bda870923dcb3e865': frozenset({'#news',
#             '#world',
#             '7.7',
#             'buildings',
#             'capital',
#             'destroys',
#             'earthquake',
#             'knocked',
#             'magnitude',
#             'nepal'}),
#  '5b17175bda870923dcb3e869': frozenset({'7.7',
#             'ace',
#             'buildings',
#             'capital',
#             'destroys',
#             'earthquake',
#             'knoc',
#             'magnitude',
#             'nepal',
#             'news',
#             'reports'}),
#  '5b17175bda870923dcb3e873': frozenset({'#khatmandu',
#             '7.7',
#             'buildings',
#             'collapse',
#             'earthquake',
#             'first',
#             'nepal',
#             'reports',
#             'several',
#             'update',
#             'victims'}),
#  '5b17175bda870923dcb3e879': frozenset({'#earthquake',
#             '#nepal',
#             'buildings',
#             'collapsed',
#             'many',
#             'reportedly',
#             '|'}),
#  '5b17175bda870923dcb3e87b': frozenset({'7.7',
#             'buildings',
#             'capital',
#             'collapse',
#             'nepal',
#             'news',
#             'quake',
#             'witnesses'}),
#  '5b17175bda870923dcb3e87d': frozenset({"'s",
#             '8.1',
#             'brought',
#             'buildings',
#             'dust',
#             'earthquake',
#             'kathmandu!people',
#             'many',
#             'massive',
#             'nepal',
#             'say'}),
#  '5b17175bda870923dcb3e889': frozenset({'7.5',
#             'brought',
#             'buildings',
#             'earthquake',
#             'kathmandu',
#             'many',
#             'massive',
#             'nepal'}),
#  '5b17175bda870923dcb3e890': frozenset({'#nepalearthquake',
#             '200',
#             '7.5',
#             'away',
#             'buildings',
#             'damaged',
#             'earthquake',
#             'hits',
#             'hour',
#             'miles',
#             'nepal',
#             'past',
#             'pokhara'}),
#  '5b17175bda870923dcb3e8a0': frozenset({'#earthquake',
#             'buildings',
#             'collapsing',
#             'dust',
#             'kathmandu',
#             'looking',
#             'nepal',
#             'ominous',
#             'present',
#             'speculation'}),
#  '5b17175bda870923dcb3e8a9': frozenset({'#india',
#             "'s",
#             '10',
#             '7.5',
#             'buildings',
#             'capital',
#             'collapsing',
#             'depth',
#             'earthquake',
#             'first',
#             'kathmandu',
#             'km',
#             'nepal',
#             'reports',
#             'struck'}),
#  '5b17175bda870923dcb3e8b6': frozenset({'7.7',
#             'buildings',
#             'capital',
#             'collapse',
#             'earthqua',
#             'nepal',
#             'quake',
#             'reuters',
#             'source',
#             'witnesses'}),
#  '5b17175bda870923dcb3e8c1': frozenset({'7.7',
#             '80',
#             'buildings',
#             'capital',
#             'collapse',
#             'earthquake',
#             'km',
#             'magnitude',
#             'measuring',
#             'nepal',
#             'quake',
#             'reuters',
#             'struck',
#             'witnesses'}),
#  '5b17175bda870923dcb3e8c3': frozenset({'#earthquake',
#             '#nepal',
#             'asian',
#             'breaking',
#             'buildings',
#             'capital',
#             'country',
#             'hits',
#             'reporters',
#             'said',
#             'shaking',
#             'strong',
#             'via',
#             'xinhua'}),
#  '5b17175bda870923dcb3e8ce': frozenset({'7.7',
#             'big',
#             'damages',
#             'higher',
#             'incoming',
#             'kathmandu',
#             'mag',
#             'nepal',
#             'one',
#             'possibly',
#             'reports'}),
#  '5b17175bda870923dcb3e8d0': frozenset({'7.5',
#             'abcnews',
#             'buildings',
#             'collapse',
#             'earthquake',
#             'magnitude',
#             'nepal'}),
#  '5b17175bda870923dcb3e8d2': frozenset({'7.5',
#             '7.7',
#             'buildings',
#             'capital',
#             'damaged',
#             'delhi',
#             'earthquake',
#             'felt',
#             'hits',
#             'kathmandu',
#             'nepal',
#             'newsbreak',
#             'north',
#             'quake',
#             'reported',
#             'strong',
#             'west'}),
#  '5b17175bda870923dcb3e921': frozenset({'7.7-magnitude',
#             'buildings',
#             'capital',
#             'collapsed',
#             'earthquake',
#             'hit',
#             'nepals',
#             'reported',
#             'yahoonews'}),
#  '5b17175bda870923dcb3e923': frozenset({'breaking',
#             'buildings',
#             'destroys',
#             'earthquake',
#             'nepal',
#             'news'}),
#  '5b17175bda870923dcb3e925': frozenset({'7.7',
#             'buildings',
#             'capital',
#             'casualties',
#             'collapse',
#             'immediate',
#             'nepal',
#             'quake',
#             'witnesses',
#             'word'}),
#  '5b17175bda870923dcb3e929': frozenset({"'s",
#             '7.5',
#             'allover',
#             'brought',
#             'buildings',
#             'dust',
#             'earthquake',
#             'kathmandu!people',
#             'many',
#             'massive',
#             'nepal',
#             'say'}),
#  '5b17175bda870923dcb3e92b': frozenset({'breakingnews',
#             'buildings',
#             'cnn',
#             'cnnbrk',
#             'earthquake',
#             'hits',
#             'ibn',
#             'major',
#             'nepal',
#             'reports',
#             'roads'}),
#  '5b17175bda870923dcb3e931': frozenset({'#empresa',
#             '7.7',
#             'buildings',
#             'capital',
#             'collapse',
#             'nepal',
#             'quake',
#             'witnesses'}),
#  '5b17175bda870923dcb3e936': frozenset({'7.7',
#             'buildings',
#             'capital',
#             'collapse',
#             'nepal',
#             'quake'}),
#  '5b17175bda870923dcb3e938': frozenset({'buildings',
#             'cnn',
#             'earthquake',
#             'hits',
#             'ibn',
#             'major',
#             'nepal',
#             'reports',
#             'roads',
#             'rt'}),
#  '5b17175bda870923dcb3e942': frozenset({'#kathmandu',
#             '#nepal',
#             'aftershock',
#             'buildings',
#             'central',
#             'earthquake',
#             'm5',
#             'm7.5',
#             'strikes'}),
#  '5b17175bda870923dcb3e94a': frozenset({'7.7-magnitude',
#             'buildings',
#             'collapsed',
#             'earthquake',
#             'nepal',
#             'say',
#             'witnesses'}),
#  '5b17175bda870923dcb3e94e': frozenset({'buildings',
#             'cnn',
#             'earthquake',
#             'ibn',
#             'major',
#             'nepal',
#             'network',
#             'reports',
#             'roads',
#             'rt',
#             'sister'}),
#  '5b17175bda870923dcb3e950': frozenset({'#usa',
#             '7.7',
#             'buildings',
#             'capital',
#             'collapse',
#             'nepal',
#             'news',
#             'quake',
#             'witnesses',
#             'world'}),
#  '5b17175bda870923dcb3e952': frozenset({'7.7',
#             'buildings',
#             'capital',
#             'collapse',
#             'nepal',
#             'news',
#             'quake',
#             'witnesses',
#             'yahoo'}),
#  '5b17175bda870923dcb3e954': frozenset({'buildings',
#             'capital',
#             'destroys',
#             'earthquake',
#             'nepal',
#             'news',
#             'sky'}),
#  '5b17175bda870923dcb3e958': frozenset({'buildings',
#             'capital',
#             'destroys',
#             'earthquake',
#             'manga',
#             'nepal'}),
#  '5b17175bda870923dcb3e96a': frozenset({'#nepal',
#             '7.4',
#             'buildings',
#             'damages',
#             'dharan',
#             'earthquake',
#             'fence',
#             'hit',
#             'kathmandu',
#             'lot',
#             'powerful',
#             'rector',
#             'reportedly',
#             'scaled',
#             'walled'}),
#  '5b17175bda870923dcb3e970': frozenset({'breakingnews',
#             'buildings',
#             'cnn',
#             'earthquake',
#             'hits',
#             'ibn',
#             'major',
#             'nepal',
#             'reports',
#             'roads'}),
#  '5b17175bda870923dcb3e976': frozenset({'7.7',
#             'breaking',
#             'buildings',
#             'capital',
#             'collapse',
#             'nepal',
#             'quake',
#             'search',
#             '|'}),
#  '5b17175bda870923dcb3e978': frozenset({'7.7',
#             'buildings',
#             'capital',
#             'coll',
#             'collapse',
#             'nepal',
#             'newssome',
#             'quake',
#             'reuters',
#             'uk',
#             'witnesses',
#             'zee'}),
#  '5b17175bda870923dcb3e98c': frozenset({'#breaking',
#             '7.7',
#             'capital',
#             'damaged',
#             'earthquake',
#             'hits',
#             'houses',
#             'kathmandu',
#             'magnitude',
#             'nepal',
#             'west'}),
#  '5b17175bda870923dcb3e9bd': frozenset({'7.7',
#             'buildings',
#             'collapsed',
#             'earthquake',
#             'hits',
#             'magnitude',
#             'nepal',
#             'reports'}),
#  '5b17175bda870923dcb3e9bf': frozenset({'buildings',
#             'earthquake',
#             'hits',
#             'major',
#             'nepal',
#             'roads'}),
#  '5b17175bda870923dcb3e9c1': frozenset({'also',
#             'buildings',
#             'cnbcpakistan',
#             'damaged',
#             'earthquake',
#             'nepal',
#             'several',
#             'update'}),
#  '5b17175bda870923dcb3e9c4': frozenset({'buildings',
#             'cnn',
#             'cnnbrk',
#             'earthquake',
#             'hits',
#             'ibn',
#             'major',
#             'nepal',
#             'reports',
#             'roads'}),
#  '5b17175bda870923dcb3e9c6': frozenset({'#breakingn',
#             'alert',
#             'buildings',
#             'cnn',
#             'cnnbrk',
#             'earthquake',
#             'hits',
#             'ibn',
#             'major',
#             'nepal',
#             'reports',
#             'roads'}),
#  '5b17175bda870923dcb3e9c8': frozenset({'#breakingnews',
#             'buildings',
#             'cnn',
#             'earthquake',
#             'hits',
#             'major',
#             'nepal',
#             'roads'}),
#  '5b17175bda870923dcb3e9cf': frozenset({'#news',
#             '#yahoonews',
#             '7.7',
#             'buildings',
#             'capital',
#             'collapse',
#             'nepal',
#             'quake',
#             'witnesses'}),
#  '5b17175bda870923dcb3e9d1': frozenset({'7.7',
#             'buildings',
#             'capital',
#             'collapse',
#             'nepal',
#             'quake',
#             'reuters',
#             'via',
#             'witnesses'}),
#  '5b17175bda870923dcb3e9d3': frozenset({'#lebanon',
#             '7.7',
#             'buildings',
#             'capital',
#             'collapse',
#             'nepal',
#             'quake',
#             'via'}),
#  '5b17175bda870923dcb3e9d5': frozenset({'#world',
#             '7.7',
#             'buildings',
#             'capital',
#             'collapse',
#             'nepal',
#             'quake'}),
#  '5b17175bda870923dcb3e9da': frozenset({'7.7',
#             'asia',
#             'buildings',
#             'capital',
#             'collapse',
#             'dtn',
#             'earthquake',
#             'meas',
#             'nepal',
#             'quake',
#             'reuters',
#             'witnesses'}),
#  '5b17175bda870923dcb3e9e4': frozenset({'buildings', 'fell', 'nepal'}),
#  '5b17175bda870923dcb3ea0c': frozenset({'7.5-mag',
#             'breaking',
#             'buildings',
#             'capital',
#             'collapsed',
#             'earthquake',
#             'kathmandu',
#             'nepal'}),
#  '5b17175bda870923dcb3ea0e': frozenset({'#breaking',
#             '7.7',
#             'buildings',
#             'capital',
#             'collapse',
#             'nepal',
#             'quake',
#             'read',
#             'witnesses'}),
#  '5b17175bda870923dcb3ea13': frozenset({'#kathmandu',
#             '7,7',
#             'buildings',
#             'collapse',
#             'earthquake',
#             'magnitude',
#             'nepal',
#             'report',
#             'several',
#             'update',
#             'victims'}),
#  '5b17175bda870923dcb3ea15': frozenset({'7.7',
#             'buildings',
#             'capital',
#             'collapse',
#             'nepal',
#             'quake',
#             'tribune',
#             'witnesses',
#             '|'}),
#  '5b17175bda870923dcb3ea1d': frozenset({'7',
#             '7.7',
#             'art',
#             'buildings',
#             'collapses',
#             'earthquake',
#             'france',
#             'magnitude',
#             'measuring',
#             'nepal'}),
#  '5b17175bda870923dcb3ea21': frozenset({'#rtgworld',
#             '7.7',
#             'buildings',
#             'capital',
#             'collapse',
#             'nepal',
#             'quake',
#             'witnesses'}),
#  '5b17175bda870923dcb3ea25': frozenset({'#news',
#             '7.7',
#             'buildings',
#             'capital',
#             'collapse',
#             'nepal',
#             'quake',
#             'reuters',
#             'witnesses'}),
#  '5b17175bda870923dcb3ea27': frozenset({'#instamood',
#             '7.7',
#             'buildings',
#             'capital',
#             'collapse',
#             'nepal',
#             'quake',
#             'witnesses'}),
#  '5b17175bda870923dcb3ea2f': frozenset({'-reuters',
#             '7.7',
#             'buildings',
#             'capital',
#             'collapse',
#             'nepal',
#             'quake',
#             'witnesses'}),
#  '5b17175bda870923dcb3ea33': frozenset({'#news',
#             '7.7',
#             'buildings',
#             'capital',
#             'collapse',
#             'nepal',
#             'quake',
#             'witnesses'}),
#  '5b17175bda870923dcb3ea4f': frozenset({"'s",
#             'buildings',
#             'centre',
#             'click',
#             'damaged',
#             'earthquake',
#             'kathmandu',
#             'nepal'}),
#  '5b17175bda870923dcb3ea56': frozenset({'7.7',
#             'buildings',
#             'capital',
#             'collapse',
#             'earthquake',
#             'magni',
#             'measuring',
#             'nepal',
#             'quake',
#             'reuters',
#             'witnesses'}),
#  '5b17175bda870923dcb3ea66': frozenset({'also',
#             'buildings',
#             'damaged',
#             'earthquake',
#             'nepal',
#             'several',
#             'update'}),
#  '5b17175bda870923dcb3ea68': frozenset({'3novices',
#             '7.7',
#             'build',
#             'buildings',
#             'capital',
#             'destroys',
#             'earthquake',
#             'knocked',
#             'magnitude',
#             'nepal'}),
#  '5b17175bda870923dcb3eab3': frozenset({'buildings',
#             'capital',
#             'collapsed',
#             'kathmandu',
#             'nepal',
#             'reuters',
#             'witness'}),
#  '5b17175bda870923dcb3eac3': frozenset({'appearing',
#             'buildings',
#             'channels',
#             'collapsed',
#             'disastrous',
#             'earthquake',
#             'friends',
#             'images',
#             'india',
#             'nepal',
#             'news',
#             'state',
#             'thoughts'}),
#  '5b17175bda870923dcb3eac5': frozenset({'7.7',
#             'buildings',
#             'capital',
#             'collapse',
#             'join',
#             'nepal',
#             'qivana',
#             'quake',
#             'witnesses'}),
#  '5b17175bda870923dcb3eacd': frozenset({'#kathmandu',
#             '#nepal',
#             '100km',
#             '7.7',
#             'aftershocks',
#             'area',
#             'buildings',
#             'collapse',
#             'earthquake',
#             'hits',
#             'reported',
#             'several',
#             'west'}),
#  '5b17175bda870923dcb3eacf': frozenset({'#kathmandu',
#             '#nepal',
#             'buildings',
#             'collapsed',
#             'damage',
#             'injuries',
#             'official',
#             'quake',
#             'reportedly',
#             'reports'}),
#  '5b17175bda870923dcb3ead5': frozenset({'#quake',
#             '7.7',
#             'buildings',
#             'capital',
#             'collapse',
#             'nepal',
#             'quake',
#             'witnesses'}),
#  '5b17175bda870923dcb3ead8': frozenset({'buildings',
#             'damaged',
#             'dust',
#             'kathmandu',
#             'many',
#             'nepal',
#             'reports',
#             'say'}),
#  '5b17175bda870923dcb3eadd': frozenset({'7.7',
#             'buildings',
#             'collapse',
#             'earthquake',
#             'nepal',
#             'quake',
#             'witnesses',
#             '|'}),
#  '5b17175bda870923dcb3eae5': frozenset({'buildings',
#             'capital',
#             'destroys',
#             'earthquake',
#             'nepal',
#             'skynews'}),
#  '5b17175bda870923dcb3eae7': frozenset({'7.7',
#             '80',
#             'buildings',
#             'collapses',
#             'earthquake',
#             'magnitude',
#             'measuring',
#             'nepal',
#             'struck'}),
#  '5b17175bda870923dcb3eaff': frozenset({"'s",
#             '7.7-magnitude',
#             'buildings',
#             'capital',
#             'collapsed',
#             'earthquake',
#             'kathmandu',
#             'nepal',
#             'say',
#             'witnesses'}),
#  '5b17175bda870923dcb3eb06': frozenset({'buildings',
#             'cnn',
#             'earthquake',
#             'hits',
#             'ibn',
#             'major',
#             'nepal',
#             'reports',
#             'roads',
#             'via'}),
#  '5b17175bda870923dcb3eb0c': frozenset({'#earthquake',
#             '#nepal',
#             'buildings',
#             'city',
#             'devastated',
#             'dust',
#             'huge',
#             'kathmandu',
#             'lots',
#             'pall',
#             'valley'}),
#  '5b17175bda870923dcb3eb0e': frozenset({'breaking',
#             'buildings',
#             'buzzfeednews',
#             'buzzfeedstorm',
#             'capital',
#             'collapsed',
#             'nepal',
#             'rt'}),
#  '5b17175bda870923dcb3eb12': frozenset({'#shoutnews',
#             'buildings',
#             'capital',
#             'destroys',
#             'earthquake',
#             'nepal'}),
#  '5b17175bda870923dcb3eb15': frozenset({'7.7',
#             'buildings',
#             'capital',
#             'collapse',
#             'earthquake',
#             'meas',
#             'nepal',
#             'quake',
#             'reuters',
#             'witnesses'}),
#  '5b17175bda870923dcb3eb17': frozenset({'buildings',
#             'cnn',
#             'cnn-',
#             'earthquake',
#             'ibn',
#             'major',
#             'nepal',
#             'network',
#             'reports',
#             'roads',
#             'sister'}),
#  '5b17175bda870923dcb3eb1f': frozenset({"'s",
#             '7.7-magnitude',
#             'buildings',
#             'capital',
#             'collapsed',
#             'earthquake',
#             'hit',
#             'kathmandu',
#             'nepal'}),
#  '5b17175bda870923dcb3eb2a': frozenset({'#earthquake',
#             '#nepal',
#             'breaking',
#             'buildings',
#             'capital',
#             'china',
#             'feels',
#             'hits',
#             'reporters',
#             'shaking',
#             'strong',
#             'xinhua'}),
#  '5b17175bda870923dcb3eb2e': frozenset({'#earthquake',
#             '#nepal',
#             'buildings',
#             'code',
#             'friends',
#             'good',
#             'hope',
#             'ok'}),
#  '5b17175bda870923dcb3eb32': frozenset({'#news',
#             '#world',
#             '7.7',
#             'buildings',
#             'capital',
#             'collapse',
#             'nepal',
#             'quake',
#             'witnesses'}),
#  '5b17175bda870923dcb3eb39': frozenset({'#quake',
#             '7.7',
#             'buildings',
#             'collapse',
#             'kathmandu',
#             'nepal'}),
#  '5b17175bda870923dcb3eb3b': frozenset({'2',
#             '3',
#             'aayi',
#             'buildings',
#             'collapse',
#             'damage',
#             'hai',
#             'nepal',
#             'news',
#             'se',
#             'yes'}),
#  '5b17175bda870923dcb3eb44': frozenset({'#breaking',
#             '#nepal',
#             '#tremors',
#             'air',
#             'badly',
#             'buildings',
#             'dust',
#             'felt',
#             'hit',
#             'many',
#             'nepal',
#             'pall',
#             'region',
#             'still',
#             'via',
#             '|'}),
#  '5b17175bda870923dcb3eb4b': frozenset({'breaking',
#             'buildings',
#             'capital',
#             'collapsed',
#             'kathmandu',
#             'nepal',
#             'reuters',
#             'witness'}),
#  '5b17175bda870923dcb3eb4f': frozenset({'7.7',
#             'buildings',
#             'capital',
#             'collapse',
#             'nepal',
#             'quake',
#             'wi',
#             '|'}),
#  '5b17175bda870923dcb3eb55': frozenset({'buildings',
#             'coming',
#             'devastated',
#             'huge',
#             'kathmandu',
#             'lots',
#             'nepal',
#             'news',
#             'prayers',
#             'quake',
#             'sad',
#             'valley'}),
#  '5b17175bda870923dcb3eb57': frozenset({'#earthquake',
#             'buildings',
#             'damaged',
#             'houses',
#             'nepal',
#             'public',
#             'several'}),
#  '5b17175cda870923dcb3eb5b': frozenset({'#worldnews',
#             '7.7',
#             'buildings',
#             'capital',
#             'collapse',
#             'nepal',
#             'news',
#             'quake',
#             'wit',
#             'world'}),
#  '5b17175cda870923dcb3eb5f': frozenset({'#earthquake',
#             '#kathmandu',
#             '#nepal',
#             "'s",
#             'buildings',
#             'capital',
#             'collapsed',
#             'eyewitness',
#             'following',
#             'm7.5',
#             'many',
#             'reports',
#             'say'}),
#  '5b17175cda870923dcb3eb61': frozenset({'7.7',
#             'buildings',
#             'capital',
#             'collapse',
#             'kilo',
#             'nepal',
#             'quake',
#             'witnesses'}),
#  '5b17175cda870923dcb3eb6d': frozenset({'buildings',
#             'collapse',
#             'earthquake',
#             'nepal',
#             'nepalearthquake',
#             'result'}),
#  '5b17175cda870923dcb3eb76': frozenset({'#earthquake',
#             '#nepal',
#             'buildings',
#             'collapsed',
#             'due'}),
#  '5b17175cda870923dcb3eb78': frozenset({'#news',
#             'buildings',
#             'capital',
#             'destroys',
#             'earthquake',
#             'info',
#             'nepal',
#             'politics'}),
#  '5b17175cda870923dcb3eb7b': frozenset({'#nepal',
#             'breaking',
#             'buildings',
#             'casualties',
#             'cracks',
#             'houses',
#             'multiple',
#             'numerous',
#             'ongoing',
#             'phone',
#             'reports',
#             'says',
#             'small',
#             'tremors'}),
#  '5b17175cda870923dcb3eb7d': frozenset({'7.7',
#             'buildings',
#             'capital',
#             'collapse',
#             'info',
#             'nepal',
#             'news',
#             'politics',
#             'quake',
#             'witnesses'}),
#  '5b17175cda870923dcb3eb80': frozenset({'across',
#             'affected',
#             'breaking',
#             'buildings',
#             'cracks',
#             'earthquake',
#             'many',
#             'mobile',
#             'nepal',
#             'news',
#             'phone',
#             'services',
#             'walls'}),
#  '5b17175cda870923dcb3eb84': frozenset({'7.7',
#             'buildings',
#             'collapsed',
#             'earthquake',
#             'magnitude',
#             'nepal',
#             'several'}),
#  '5b17175cda870923dcb3eb86': frozenset({'#news',
#             '7.7',
#             'buildings',
#             'capital',
#             'collapse',
#             'nepal',
#             'quake',
#             'usa',
#             'witnesses',
#             'world'}),
#  '5b17175cda870923dcb3eb88': frozenset({'buildings', 'many', 'nepal'}),
#  '5b17175cda870923dcb3eb8c': frozenset({'#reuters',
#             '7.7',
#             'buildings',
#             'capital',
#             'collapse',
#             'nepal',
#             'quake',
#             'witnesses',
#             'world'}),
#  '5b17175cda870923dcb3eb8e': frozenset({'7.7',
#             'buildings',
#             'collapses',
#             'earthquake',
#             'magnitude',
#             'measur',
#             'nepal'}),
#  '5b17175cda870923dcb3eb9b': frozenset({'7.7',
#             'buildings',
#             'capital',
#             'collapse',
#             'nepal',
#             'quake',
#             'via',
#             'witnesses'}),
#  '5b17175cda870923dcb3eba2': frozenset({'#news',
#             '#world',
#             '7.7',
#             'buildings',
#             'capital',
#             'collapse',
#             'earthquake',
#             'nepal',
#             'quake',
#             'reuters',
#             'witnesses'}),
#  '5b17175cda870923dcb3eba6': frozenset({'7.7',
#             'buildings',
#             'capital',
#             'collapse',
#             'londra',
#             'nepal',
#             'quake',
#             'qui',
#             'radio',
#             'witnesses'}),
#  '5b17175cda870923dcb3eba9': frozenset({'7.7',
#             'buildings',
#             'capital',
#             'collapse',
#             'nepal',
#             'quake',
#             'reuters',
#             'witnesses'}),
#  '5b17175cda870923dcb3ebab': frozenset({'#empathytherapyrules',
#             '7.7',
#             'buildings',
#             'capital',
#             'collapse',
#             'nepal',
#             'quake',
#             'witnesses'}),
#  '5b17175cda870923dcb3ebad': frozenset({'#anonhqnews',
#             '7.7',
#             'buildings',
#             'capital',
#             'collapse',
#             'earthquake',
#             'nepal',
#             'quake',
#             'reuters',
#             'witnesses'}),
#  '5b17175cda870923dcb3ebbf': frozenset({'#news',
#             '#worldnews',
#             '7.7',
#             'buildings',
#             'capital',
#             'collapse',
#             'earthqua',
#             'nepal',
#             'quake',
#             'reuters',
#             'witnesses'}),
#  '5b17175cda870923dcb3ebc5': frozenset({'#world',
#             '7.7',
#             'buildings',
#             'capital',
#             'collapse',
#             'nepal',
#             'quake',
#             'witnesses'}),
#  '5b17175cda870923dcb3ebd7': frozenset({'#earthquake',
#             'buildings',
#             'damage',
#             'epicenter',
#             'kathmandu',
#             'massive',
#             'nepal',
#             'ppl',
#             'quake',
#             'r',
#             'relatives',
#             'resulting',
#             'safe',
#             'talked',
#             'thankfully'}),
#  '5b17175cda870923dcb3ebef': frozenset({'#reuters',
#             '7.7',
#             'buildings',
#             'capital',
#             'collapse',
#             'earthquake',
#             'measu',
#             'nepal',
#             'quake',
#             'reuters',
#             'witnesses'}),
#  '5b17175cda870923dcb3ec09': frozenset({'#reutersworldnews',
#             '7.7',
#             'buildings',
#             'capital',
#             'collapse',
#             'earthqu',
#             'nepal',
#             'quake',
#             'reuters',
#             'witnesses'}),
#  '5b17175cda870923dcb3ec0b': frozenset({'#janzournews',
#             '7.7',
#             'buildings',
#             'capital',
#             'collapse',
#             'libya',
#             'nepal',
#             'quake',
#             'reuters',
#             'witnesses'}),
#  '5b17175cda870923dcb3ec15': frozenset({'7.7',
#             'buildings',
#             'capital',
#             'collapse',
#             'earthquake',
#             'mea',
#             'nepal',
#             'quake',
#             'reuters',
#             'witnesses'}),
#  '5b17175cda870923dcb3ec1b': frozenset({'#worldnews',
#             '7.7',
#             'buildings',
#             'capital',
#             'collapse',
#             'earthquake',
#             'mea',
#             'nepal',
#             'quake',
#             'reuters',
#             'witnesses'}),
#  '5b17175cda870923dcb3ec1d': frozenset({'#news',
#             '7.7',
#             'buildings',
#             'capital',
#             'collapse',
#             'nepal',
#             'quake',
#             'via',
#             'witnesses'}),
#  '5b17175cda870923dcb3ec1f': frozenset({'7.7',
#             'arlington',
#             'buildings',
#             'capital',
#             'collapse',
#             'nepal',
#             'quake',
#             'reute',
#             'witnesses'}),
#  '5b17175cda870923dcb3ec51': frozenset({'7.7',
#             'breaking',
#             'delhi',
#             'earthquake',
#             'far',
#             'felt',
#             'magnitude',
#             'measuring',
#             'nepal',
#             'orissa',
#             'parts',
#             'patna',
#             'tremors'}),
#  '5b17175cda870923dcb3ec5f': frozenset({"'m",
#             'bhaktapur',
#             'buildings',
#             'damage',
#             'damaged',
#             'huge',
#             'kathmandu',
#             'made',
#             'n',
#             'nope',
#             'old',
#             'sure'}),
#  '5b17175cda870923dcb3ec67': frozenset({'#earthquake',
#             'buildings',
#             'centre',
#             'delhi',
#             'epic',
#             'evacuated',
#             'gujarat',
#             'india',
#             'nepal'}),
#  '5b17175cda870923dcb3eca5': frozenset({'7.7',
#             'buildings',
#             'capital',
#             'destroys',
#             'dow',
#             'earthquake',
#             'knocked',
#             'magnitude',
#             'nepal'}),
#  '5b17175cda870923dcb3ecb5': frozenset({'#certified',
#             '#teamfollowback',
#             '7.7',
#             'buildings',
#             'capital',
#             'destroys',
#             'earthquake',
#             'magnitude',
#             'nepal'}),
#  '5b17175cda870923dcb3ecbf': frozenset({'7.7',
#             '^~^',
#             'buildings',
#             'capital',
#             'collapse',
#             'nepal',
#             'quake',
#             'witnesses',
#             '|'}),
#  '5b17175cda870923dcb3ecc1': frozenset({'#newspipeline',
#             '7.7',
#             'buildings',
#             'capital',
#             'collapse',
#             'nepal',
#             'quake',
#             'witnesses'}),
#  '5b17175cda870923dcb3ecc5': frozenset({'7.5',
#             '80',
#             'buildings',
#             'collapsing',
#             'earthquake',
#             'east',
#             'epicentre',
#             'kathmandu',
#             'kilometres',
#             'magnitude',
#             'nepal',
#             'pokhara',
#             'reports',
#             '|'}),
#  '5b17175cda870923dcb3ecca': frozenset({'7.7',
#             'buildings',
#             'capital',
#             'clinic',
#             'collapse',
#             'nepal',
#             'quake',
#             'witnesses'}),
#  '5b17175cda870923dcb3eccc': frozenset({'7.7',
#             'buildings',
#             'capital',
#             'collapse',
#             'md',
#             'media',
#             'nepal',
#             'quake',
#             'witnesses'}),
#  '5b17175cda870923dcb3ecce': frozenset({'7.7',
#             'buildings',
#             'capital',
#             'collapse',
#             'medical',
#             'nepal',
#             'quake',
#             'witnesses'}),
#  '5b17175cda870923dcb3ecd0': frozenset({'$',
#             '7.7',
#             'buildings',
#             'capital',
#             'collapse',
#             'nepal',
#             'quake',
#             'texas',
#             'witnesses'}),
#  '5b17175cda870923dcb3ecd2': frozenset({'$',
#             '7.7',
#             'buildings',
#             'capital',
#             'collapse',
#             'nc',
#             'nepal',
#             'quake',
#             'witnesses'}),
#  '5b17175cda870923dcb3ecd4': frozenset({'7.7',
#             'buildings',
#             'capital',
#             'collapse',
#             'earthquake',
#             'mea',
#             'nepal',
#             'quake',
#             'reuters',
#             'witnesses',
#             'worldnews'}),
#  '5b17175cda870923dcb3ecda': frozenset({'#mn',
#             '7.7',
#             'buildings',
#             'capital',
#             'collapse',
#             'nepal',
#             'quake',
#             'witnesses'}),
#  '5b17175cda870923dcb3ecdc': frozenset({'7.7',
#             'buildings',
#             'canada',
#             'capital',
#             'collapse',
#             'nepal',
#             'quake',
#             'witnesses',
#             'world'}),
#  '5b17175cda870923dcb3ecde': frozenset({'#airport',
#             '7.7',
#             'buildings',
#             'capital',
#             'collapse',
#             'nepal',
#             'quake',
#             'reuters',
#             'witnesses'}),
#  '5b17175cda870923dcb3ece0': frozenset({'7.7',
#             'buildings',
#             'capital',
#             'collapse',
#             'nepal',
#             'news',
#             'quake',
#             'reuters',
#             'witnesses',
#             'world'}),
#  '5b17175cda870923dcb3ece2': frozenset({'7.7',
#             'buildings',
#             'capital',
#             'collapse',
#             'nepal',
#             'quake',
#             'reuters',
#             'witnesses',
#             '|'}),
#  '5b17175cda870923dcb3ece4': frozenset({'#breakingnews',
#             '7.7',
#             'buildings',
#             'capital',
#             'collapse',
#             'nepal',
#             'quake',
#             'witnesses'}),
#  '5b17175cda870923dcb3ece9': frozenset({'#nepal',
#             'buildings',
#             'collapsed',
#             'earthquake',
#             'families',
#             'friends',
#             'gripped',
#             'looking',
#             'many',
#             'panic',
#             'people',
#             'relatives',
#             'reportedly'}),
#  '5b17175cda870923dcb3eceb': frozenset({'7.5',
#             '80k',
#             'buildings',
#             'damage',
#             'earthquake',
#             'east',
#             'nepal',
#             'pokhara',
#             'reported',
#             'western'}),
# ...
#             'prayers'}),
#  '5b17175dda870923dcb42cde': frozenset({'6',
#             'ago',
#             'bbc',
#             'earthquake',
#             'minute',
#             'nepal',
#             'news',
#             'strikes',
#             'strong'}),
#  '5b17175dda870923dcb42ce1': frozenset({'7.5-magnitude',
#             'earthquake',
#             'felt',
#             'india',
#             'nepal',
#             'strikes'}),
#  '5b17175dda870923dcb42d47': frozenset({"'s",
#             '7.7',
#             'also',
#             'capital',
#             'damage',
#             'delhi',
#             'developing',
#             'earthquake',
#             'felt',
#             'kathmandu',
#             'magnitude',
#             'nepal',
#             'new',
#             'reported',
#             'soon',
#             'tremors'}),
#  '5b17175dda870923dcb42d63': frozenset({'7.4',
#             'breaking',
#             'cities',
#             'earthquake',
#             'epicenter',
#             'felt',
#             'indian',
#             'magnitude',
#             'media',
#             'nepal',
#             'pakistan',
#             'peshawar',
#             'reports',
#             'several',
#             'tremors'}),
#  '5b17175dda870923dcb42d65': frozenset({'#acenewsreport',
#             'capital',
#             'earthquake',
#             'kathmandu',
#             'nepal',
#             'powerful',
#             'strikes',
#             'strong',
#             'west'}),
#  '5b17175dda870923dcb42d88': frozenset({'earthquake',
#             'near',
#             'nepal',
#             'people',
#             'thoughts'}),
#  '5b17175dda870923dcb42d8b': frozenset({'#earthquake',
#             '#nepal',
#             'duck',
#             'get',
#             'hold',
#             'open',
#             'panic',
#             'safe',
#             'space',
#             'stay'}),
#  '5b17175dda870923dcb42d8e': frozenset({'#prayfronepal',
#             '#quake',
#             'capital',
#             'damage',
#             'earthquake',
#             'felt',
#             'nepals',
#             'reported',
#             'strong'}),
#  '5b17175dda870923dcb42daf': frozenset({'#nepal',
#             '7.5-magnitude',
#             'breaking',
#             'earthquake',
#             'hit',
#             'saturday.(geofon'}),
#  '5b17175dda870923dcb42dc0': frozenset({'7.7',
#             'channel',
#             'earthquake',
#             'magnitude',
#             'measuring',
#             'nepal',
#             'newsasia',
#             'strikes',
#             'usgs'}),
#  '5b17175dda870923dcb42dc2': frozenset({'7.5',
#             'damage',
#             'earthquake',
#             'foxnews',
#             'hits',
#             'magnitude',
#             'nepal',
#             'reported'}),
#  '5b17175dda870923dcb42dd3': frozenset({'35',
#             'e',
#             'info',
#             'km',
#             'lamjung',
#             'looks',
#             'm7.5',
#             'nepal',
#             'severe',
#             'usgs'}),
#  '5b17175dda870923dcb42dda': frozenset({'2015',
#             '25',
#             '2:11',
#             '35km',
#             '7.5',
#             'april',
#             'breaking',
#             'earthquake',
#             'east',
#             'hits',
#             'lamjung',
#             'magnitude',
#             'nepal',
#             'pm',
#             'today',
#             'via'}),
#  '5b17175dda870923dcb42ddd': frozenset({'#aranikohighway',
#             '#earthquake',
#             'crying',
#             'destruction',
#             'huge',
#             'lokanthali',
#             'nepal',
#             'people',
#             'rt',
#             'worrying'}),
#  '5b17175dda870923dcb42dec': frozenset({'#earthquake',
#             '#india',
#             '#nepal',
#             'amp',
#             'everyone',
#             'hope',
#             'safe',
#             'sound'}),
#  '5b17175dda870923dcb42dee': frozenset({'beloved',
#             'brother',
#             'hope',
#             'nepal',
#             'raju',
#             'safe'}),
#  '5b17175dda870923dcb42df0': frozenset({'center', 'earthquake', 'nepal'}),
#  '5b17175dda870923dcb42df8': frozenset({'earthquake',
#             'everyone',
#             'hope',
#             'nepal',
#             'pic',
#             'safe'}),
#  '5b17175dda870923dcb42e14': frozenset({'#earthquake',
#             '#kathmandu',
#             'nepal',
#             'praying',
#             'well'}),
#  '5b17175dda870923dcb42e16': frozenset({'earthquake',
#             'ever',
#             'flood',
#             'hmm',
#             'media',
#             'nepal',
#             'opinion',
#             'pm',
#             'rain',
#             'tour',
#             'travel',
#             'ya'}),
#  '5b17175dda870923dcb42e18': frozenset({'#earthquake',
#             '#prayers',
#             'everyone',
#             'hope',
#             'nepal',
#             'safe'}),
#  '5b17175dda870923dcb42e1a': frozenset({'7.5',
#             'amp',
#             'bihar',
#             'delhi',
#             'earthquake',
#             'felt',
#             'haryana',
#             'india',
#             'major',
#             'ncr',
#             'nepal',
#             'recorded',
#             'shakes',
#             'sikkim',
#             'tremors',
#             'wb'}),
#  '5b17175dda870923dcb42e21': frozenset({'#earthquake',
#             'affected',
#             'amp',
#             'finding',
#             'info',
#             'modi',
#             'pm',
#             'process',
#             'reach',
#             'working'}),
#  '5b17175dda870923dcb42e3b': frozenset({'#earthquake',
#             '#nepal',
#             'killed',
#             'know',
#             'many',
#             'mt',
#             "n't",
#             'saved',
#             'terrible'}),
#  '5b17175dda870923dcb42e51': frozenset({'7.5',
#             'across',
#             'click',
#             'eastern',
#             'epicentre',
#             'felt',
#             'india',
#             'measured',
#             'nepal',
#             'north',
#             'tremors'}),
#  '5b17175dda870923dcb42e55': frozenset({'case',
#             'causes',
#             'earthquake',
#             'great',
#             'india',
#             'nepal',
#             'statement',
#             'tremors',
#             'unlikely'}),
#  '5b17175dda870923dcb42e57': frozenset({'#topnews',
#             'earthquake',
#             'nepal',
#             'strikes',
#             'strong'}),
#  '5b17175dda870923dcb42e5b': frozenset({'#earthquake',
#             'around',
#             'awful',
#             'everyone',
#             'kathmandu',
#             'nepal',
#             'news',
#             'prayers'}),
#  '5b17175dda870923dcb42e5f': frozenset({'#earthquake',
#             '7.5',
#             'magnitude',
#             'nepal',
#             'pakistan',
#             'people',
#             'pray',
#             'safety'}),
#  '5b17175dda870923dcb42e61': frozenset({'almost',
#             'breaking',
#             'earthquake',
#             'epicenter',
#             'indian',
#             'nepal',
#             'news',
#             'strong',
#             'subcontinent',
#             'whole'}),
#  '5b17175dda870923dcb42e96': frozenset({'#earthquake',
#             '#kathmandu',
#             'fucking',
#             'nepal',
#             'rt',
#             'scary'}),
#  '5b17175dda870923dcb42f12': frozenset({'7.7-magnitude',
#             'breaking',
#             'earthquake',
#             'nepal',
#             'strikes'}),
#  '5b17175dda870923dcb42f8a': frozenset({'35',
#             '7.5',
#             'breaking',
#             'earthquake',
#             'east',
#             'hits',
#             'kilometers',
#             'lamjung',
#             'magnitude',
#             'nepal',
#             'says',
#             'usgs'}),
#  '5b17175dda870923dcb42f8d': frozenset({'#earthquake',
#             '#nepal',
#             'continuing',
#             'everyone',
#             'felt',
#             'prayers',
#             'tremors'}),
#  '5b17175dda870923dcb42f94': frozenset({'#nepal',
#             '12',
#             '7.7',
#             'deep',
#             'earthquake',
#             'km',
#             'shakemap',
#             'usga'}),
#  '5b17175dda870923dcb42f9c': frozenset({'#earthquake',
#             '#nepal',
#             'everyone',
#             'hope',
#             'ok',
#             'today'}),
#  '5b17175dda870923dcb43018': frozenset({'#earthquake',
#             'airforce',
#             'alert',
#             'amp',
#             'bareilly',
#             'chandigarh',
#             'govt',
#             'gwalior',
#             'high',
#             'hindon',
#             'indian',
#             'nepal',
#             'put',
#             'reacts',
#             'relief',
#             'sarsawa',
#             'station'}),
#  '5b17175dda870923dcb43074': frozenset({'damage',
#             'delhi',
#             'earthquake',
#             'felt',
#             'hope',
#             'jaipur',
#             'kolkata',
#             'minimum',
#             'nepal',
#             'omg'}),
#  '5b17175dda870923dcb4308b': frozenset({'across',
#             'earthquake',
#             'felt',
#             'india',
#             'massive',
#             'nepal',
#             'north',
#             'tremors'}),
#  '5b17175dda870923dcb4308f': frozenset({'earthquake',
#             'epicenter',
#             'lamjung',
#             'nepal',
#             'usgs'}),
#  '5b17175dda870923dcb43091': frozenset({'7.5',
#             'earthquake',
#             'magnitude',
#             'nepal'}),
#  '5b17175dda870923dcb43094': frozenset({'2015',
#             '25',
#             '2:11',
#             '35km',
#             '7.5',
#             'april',
#             'earthquake',
#             'east',
#             'hits',
#             'icymi',
#             'lamjung',
#             'magnitude',
#             'nepal',
#             'pm',
#             'today',
#             'via'}),
#  '5b17175dda870923dcb43096': frozenset({'#nepal',
#             "'s",
#             '7.5',
#             'earthquake',
#             'strong'}),
#  '5b17175dda870923dcb43099': frozenset({'#nepal',
#             'damage',
#             'earthquake',
#             'road'}),
#  '5b17175dda870923dcb4309c': frozenset({'#breaking',
#             '#kathmandu',
#             '#nepal',
#             '7.5',
#             'damage',
#             'earthquake',
#             'magnitude',
#             'reported'}),
#  '5b17175dda870923dcb430a0': frozenset({'#earthquake',
#             '2',
#             '7.4',
#             'amp',
#             'covering',
#             'epicentre',
#             'felt',
#             'india',
#             'jaipur',
#             'kolkatta',
#             'magnit',
#             'mild',
#             'nepal',
#             'north',
#             'ones',
#             'pune',
#             'tamilnadu',
#             'tremors'}),
#  '5b17175dda870923dcb430a2': frozenset({'#kathmandu',
#             'earthquake',
#             'nepal',
#             'shake'}),
#  '5b17175dda870923dcb430a4': frozenset({'#earthquake',
#             '#savenepal',
#             '7.5',
#             'earthquake',
#             'epicenter',
#             'magnitude',
#             'nepal'}),
#  '5b17175dda870923dcb430a9': frozenset({'7.7',
#             '80',
#             'earthquake',
#             'east',
#             'km',
#             'magnitude',
#             'measuring',
#             'nepal',
#             'pokhara',
#             'rt',
#             'strikes',
#             'timesnow'}),
#  '5b17175dda870923dcb430ad': frozenset({'#odisha',
#             '7.4',
#             'agencies',
#             'earthquake',
#             'epicentre',
#             'nepal',
#             'region',
#             'richter',
#             'says',
#             'scale',
#             'us'}),
#  '5b17175dda870923dcb430ea': frozenset({'#earthquake',
#             '#nepal',
#             '7.7',
#             'magnitude',
#             'massive'}),
#  '5b17175dda870923dcb430f6': frozenset({'#earthquake',
#             '#nepal',
#             'blocked',
#             'killed',
#             'know',
#             'many',
#             "n't",
#             'roads',
#             'rt',
#             'saved',
#             'terrible'}),
#  '5b17175dda870923dcb430f8': frozenset({'#followback',
#             'capital',
#             'earthquake',
#             'follow',
#             'kathm',
#             'nepal',
#             'powerful',
#             'strikes',
#             'strong',
#             'west'}),
#  '5b17175dda870923dcb431aa': frozenset({'06:11',
#             '88',
#             'apr-25',
#             'earthquake',
#             'major',
#             'min',
#             'nepal',
#             'quake',
#             'tweets',
#             'utc'}),
#  '5b17175dda870923dcb431be': frozenset({"'s",
#             'breaking',
#             'damage',
#             'earthquake',
#             'expects',
#             'geological',
#             'heavy',
#             'hits',
#             'kathmandu',
#             'magnitude-7.5',
#             'near',
#             'nepal',
#             'says',
#             'survey',
#             'u.s.'}),
#  '5b17175dda870923dcb431c2': frozenset({'#nepal',
#             '7.5',
#             'earthquake',
#             'hope',
#             'safe',
#             'terrible'}),
#  '5b17175dda870923dcb431ca': frozenset({'#earthquake', 'impact', 'nepal'}),
#  '5b17175dda870923dcb431ce': frozenset({'aftr', 'earthquake', 'nepal'}),
#  '5b17175dda870923dcb431d0': frozenset({'#earthquake',
#             'gandhi',
#             'gone',
#             'india',
#             'kedarnath',
#             'massive',
#             'nepal',
#             'rahul',
#             'today',
#             'went',
#             'yesterday'}),
#  '5b17175dda870923dcb431d2': frozenset({'#newsintweets',
#             '7.5',
#             'abc',
#             'developing',
#             'magnitude',
#             'news',
#             'preliminary',
#             'significant',
#             'usgs'}),
#  '5b17175dda870923dcb43296': frozenset({'#earthquake',
#             "'s",
#             'also',
#             'come',
#             'earthquake',
#             'experienced',
#             'india',
#             'modi',
#             'nepal',
#             'news',
#             'parts',
#             'pm',
#             'several',
#             'tremors',
#             'tweet'}),
#  '5b17175dda870923dcb43298': frozenset({'#earthquake',
#             '#nepal',
#             '7.5',
#             'earthquake',
#             'epicentre',
#             'lamjung',
#             'richter',
#             'scale'}),
#  '5b17175dda870923dcb432a0': frozenset({'#earthquake',
#             '2015',
#             '25',
#             '7.7',
#             'april',
#             'channel',
#             'hits',
#             'moment',
#             'nepal',
#             'rt',
#             'shows',
#             'studio',
#             'tv',
#             'video'}),
#  '5b17175dda870923dcb432a2': frozenset({'#prkdr',
#             'earthquake',
#             'nepal',
#             'powerful',
#             'strikes',
#             'strong',
#             'west'}),
#  '5b17175dda870923dcb432ad': frozenset({'#earthquake',
#             '11',
#             'ago',
#             'info',
#             'min',
#             'nepal',
#             'powerful',
#             'shakes'}),
#  '5b17175dda870923dcb432bb': frozenset({'#earthquake',
#             'building',
#             'coalpsed',
#             'near',
#             'nepal',
#             'new',
#             'road'}),
#  '5b17175dda870923dcb432c0': frozenset({'#earthquake',
#             '2check',
#             'aftershocks',
#             'called',
#             'experiencing',
#             'folks',
#             'india/',
#             'safe',
#             'stay',
#             'still',
#             'th',
#             'tre',
#             'vr',
#             'wth'}),
#  '5b17175dda870923dcb432c4': frozenset({'7.5',
#             'earthquake',
#             'east',
#             'india',
#             'nepal',
#             'north',
#             'richter',
#             'scale'}),
#  '5b17175dda870923dcb432ca': frozenset({'#nepal',
#             'airport',
#             'earthquake',
#             'khatmandu',
#             'ops',
#             'reportedly',
#             'suspended'}),
#  '5b17175dda870923dcb432f1': frozenset({'#earthquake',
#             '#nepal',
#             'blocked',
#             'building',
#             'fell',
#             'roads',
#             'rt'}),
#  '5b17175dda870923dcb432f5': frozenset({'#earthquake',
#             'guys',
#             'kathmandu',
#             'nepal',
#             'safe',
#             'stay'}),
#  ...}

# %%
sim_c.cache_info()
# Out:
# CacheInfo(hits=327495, misses=72795, maxsize=1073741824, currsize=72795)

# %%
@lru_cache(maxsize=2**30)
def sim_l(tokens_a, tokens_b):
    return ft_comp.n_similarity(tokens_a, tokens_b)


def mmr3(docs, query, l):
    def mmr_score(tweet):
        return l * sim_l(docs[tweet], query) - \
               (1 - l) * max([sim_l(docs[tweet], docs[y]) for y in set(selected) - {tweet}] or [0])


    selected = set()
    while selected != set(docs):
        remaining = list(set(docs) - selected)
        next_selected = max(remaining, key=mmr_score)

        selected.add(next_selected)
        yield next_selected

# %%
sim_l.cache_clear()

# %%
# %%time

for i, obj in enumerate(mmr3(tweets_tokens, topic_tokens, 0.6)):
    print(obj)
    if i == 10:
        break
# Out:
# 5b17172ada870923dcb095b6
# 5b17172ada870923dcb09245
# 5b171729da870923dcb08977
# 5b171729da870923dcb08b23
# 5b171729da870923dcb08894
# 5b171729da870923dcb08de7
# 5b17172ada870923dcb09414
# 5b171729da870923dcb08e25
# 5b17172ada870923dcb09379
# 5b171729da870923dcb08ac5
# 5b171729da870923dcb08c2c
# CPU times: user 5.21 s, sys: 0 ns, total: 5.21 s
# Wall time: 5.2 s

# %%
import ipyparallel as ipp
    
ids = list(tweets_tokens.keys())

for i, tid in enumerate(mmr2(range(len(ids)))):
    print(tweets_tokens[ids[tid]])
    if i == 10:
        break
# Out:
# [0, 1, 2, 3]
# /home/mquezada/anaconda3/envs/news-model/lib/python3.6/site-packages/ipyparallel/client/client.py:459: RuntimeWarning:
#             Controller appears to be listening on localhost, but not on this machine.
#             If this is true, you should specify Client(...,sshserver='you@mquezada-MS-7A46')
#             or instruct your controller to listen on an external IP.
#   RuntimeWarning)
# ['Hello, World', 'Hello, World', 'Hello, World', 'Hello, World']
