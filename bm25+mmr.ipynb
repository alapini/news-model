# %%
from scipy.linalg import norm
from numba import jit
import random
import multiprocessing
import re
from operator import itemgetter

import logging
from collections import defaultdict
from functools import lru_cache
from pathlib import Path
from numba import jit
import numpy as np

import spacy
from bson.objectid import ObjectId
from gensim.models import KeyedVectors
from nltk.corpus import stopwords
from pymongo import MongoClient
from tqdm import tqdm

logging.basicConfig(format='%(asctime)s : %(message)s', level=logging.INFO)
_info = logging.info

client = MongoClient('mongodb://localhost:27017')
db = client.twitter_news
nlp = spacy.load('en_core_web_sm', tagger=False, entity=False, matcher=False)

def hashtag_pipe(doc):
    merged_hashtag = False
    while True:
        for token_index, token in enumerate(doc):
            if token.text == '#':
                if token.head is not None:
                    start_index = token.idx
                    end_index = start_index + len(token.head.text) + 1
                    if doc.merge(start_index, end_index) is not None:
                        merged_hashtag = True
                        break
        if not merged_hashtag:
            break
        merged_hashtag = False
    return doc


nlp.add_pipe(hashtag_pipe)

# %%
total_events = 3


@lru_cache(maxsize=total_events)
def get_representatives(event_id):
    _info("getting representatives")
    representatives = db.representatives.find({'event': ObjectId(event_id)})
    return list(representatives)


@lru_cache(maxsize=total_events)
def get_topics(event_id):
    _info("getting topics")
    topics = list(db.topics.find({'event': ObjectId(event_id)}))
    comodin = None
    for t in topics:
        if t['topic_name'] == "Non relevant":
            comodin = t
            topics.remove(t)
            break
    return topics, comodin


@lru_cache(maxsize=1)
def get_events():
    _info("getting events")
    events = db.events.find()
    return list(events)


@lru_cache(maxsize=1)
def get_tweets(a=None):
    _info('getting all tweets')
    all_tweets = db.tweets.find()
    return list(all_tweets)


@lru_cache(maxsize=3)
def get_vectors(path):
    _info(f"loading fasttext vectors from {path}")
    word_vectors = KeyedVectors.load_word2vec_format(path)
    return word_vectors


@lru_cache(maxsize=2**30)
def sim(tokens_a, tokens_b):
    return ft_comp.n_similarity(tokens_a, tokens_b)


def mmr(docs, query, l):
    def mmr_score(tweet):
        return l * sim(docs[tweet], query) - \
               (1 - l) * max([sim(docs[tweet], docs[y]) for y in set(selected) - {tweet}] or [0])

    L = np.array([[l, 0], [0, l - 1]])

    def score(tweet):
        s1 = sim(docs[tweet], query)
        s2 = np.max(np.array([sim(docs[tweet], docs[y]) for y in set(selected) - {tweet}] or [0]))

        return L.dot(np.array([s1, s2])).sum()

    selected = set()
    while selected != set(docs):
        remaining = list(set(docs) - selected)
        next_selected = max(remaining, key=mmr_score)
        # next_selected = remaining[np.argmax([score(t) for t in remaining])]

        # next_selected = None
        # max_score = 0
        #
        # for _t in remaining:
        #     score = l * sim(docs[_t], query) - \
        #             (1 - l) * max([sim(docs[_t], docs[y]) for y in set(selected) - {_t}] or [0])
        #     if score > max_score:
        #         max_score = score
        #         next_selected = _t

        selected.add(next_selected)
        yield next_selected, ' '.join(list(docs[next_selected]))


@lru_cache(maxsize=total_events)
def process_tweets(event_id):
    all_tweets = get_tweets()
    representatives = get_representatives(event_id)

    _info("processing tweets")

    # rep_tweet: repr_id => tweet
    rep_tweet = dict()
    for t in tqdm(all_tweets):
        rep_tweet[t['representative']] = t

    # repr_ids: {repr_id} // this event
    repr_ids = set([r['_id'] for r in representatives])

    # tweets_this_event: [tweet]
    tweets_this_event_ = [t for r, t in rep_tweet.items() if r in repr_ids]
    tweets_this_event = []
    
    # filter out tweets wo expanded urls
    for t in tweets_this_event_:
        e_u = t['expanded_urls']
        if all(u is not None for u in e_u):
            tweets_this_event.append(t)    

    tweets_tokens = dict()
    all_tokens = set()
    for tweet, doc in tqdm(zip(tweets_this_event, nlp.pipe([_t['text'] for _t in tweets_this_event],
                                                           n_threads=8)),
                           total=len(tweets_this_event)):

        tokens = frozenset([token.lower_
                            for token in doc
                            if token.lower_ not in stopwords.words('english') and token.lower_ in ft_comp])

        if tokens and tokens not in all_tokens:
            tweets_tokens[str(tweet['_id'])] = tokens
            all_tokens.add(tokens)

    return tweets_tokens


def expand_query(topics):
    # query expansion 
    topics_this_event = []
    for topic in topics:
        new_words = set()
        for keyword in topic:
            new_words |= set([word for word, _ in ft_comp.most_similar(keyword, topn=25)])
        new_topic = set(topic) | new_words
        topics_this_event.append(new_topic)
    return topics_this_event

# %%
path = Path('/home/mquezada/anchor-text-twitter/data/ft_alltweets_model.vec')
ft_comp = get_vectors(path.as_posix())
data_path = Path('/home/mquezada/tweet_topics/')
# Out:
# 2018-07-06 16:11:54,528 : loading fasttext vectors from /home/mquezada/anchor-text-twitter/data/ft_alltweets_model.vec
# 2018-07-06 16:11:54,532 : loading projection weights from /home/mquezada/anchor-text-twitter/data/ft_alltweets_model.vec
# 2018-07-06 16:12:55,043 : loaded (1076139, 100) matrix from /home/mquezada/anchor-text-twitter/data/ft_alltweets_model.vec

# %%
#### BM25 RELEVANCE RANKING

events = get_events()
topics = list()

for event in events:
    topics.append([frozenset(topic['keywords'])
                   for topic in get_topics(event['_id'])[0]])

for EVENT_NO in (0, 1, 2):
    event = events[EVENT_NO]
    print(event['event_name'])
    event_id = event['_id']
        
    _info("expanding queries")
    
    # query expansion        
    topics_this_event = expand_query(topics[EVENT_NO])
    
    _info("processing tweets")
    tweet_tokens = process_tweets(event_id)

    _info("dictionaries for bm25")
    query_terms = set()
    for topic in topics_this_event:
        for term in topic:
            query_terms.add(term)
            
    ##### f(q_i, D)
    query_freqs = defaultdict(dict)

    ##### avgdl
    avgdl = 0

    ###### n(q_i)
    n_q_i = defaultdict(int)

    ###### |D|
    sizeof_D = len(tweet_tokens)

    for tweet_id, tokens in tqdm(tweet_tokens.items(), total=sizeof_D):
        for term in query_terms:
            if term in tokens:
                query_freqs[tweet_id][term] = 1
                n_q_i[term] += 1
        avgdl += len(tokens)

    avgdl = avgdl / sizeof_D
    
    k_1 = 1.2
    b = 0.75
    C1 = k_1 * (1 - b + b * (sizeof_D / avgdl))  # 634.7016801700094
    C2 = k_1 + 1  # 2.2

    def IDF(term):
        return np.log((sizeof_D - n_q_i[term] + .5) / (n_q_i[term] + .5))

    def BM25(query, tweet_id):
        score = 0
        for q_i in query:
            f_q_i = query_freqs[tweet_id].get(q_i, 0)

            score += IDF(q_i) * (f_q_i * C2) / (f_q_i + C1)
        return score
    
    def compute_bm25(query):
        scores_q_i = dict()
        for tweet_id, doc in tqdm(tweet_tokens.items(), total=sizeof_D):
            score = BM25(query, tweet_id)
            if score > 0:
# 100%|██████████| 34275/34275 [00:13<00:00, 2455.03it/s]
# 2018-07-06 16:17:28,576 : expanding queries
# saving data
# done
# nepal_tweets.tsv
# 2018-07-06 16:17:29,449 : processing tweets
# 2018-07-06 16:17:29,450 : getting representatives
# 2018-07-06 16:17:29,869 : processing tweets
# 100%|██████████| 642251/642251 [00:00<00:00, 1107062.78it/s]
# 100%|██████████| 123964/123964 [06:14<00:00, 330.84it/s]
# 2018-07-06 16:23:45,457 : dictionaries for bm25
# 100%|██████████| 76533/76533 [00:03<00:00, 24254.68it/s]
# computing bm25 for 10 topics
# 100%|██████████| 76533/76533 [00:13<00:00, 5688.39it/s]
# 100%|██████████| 76533/76533 [00:13<00:00, 5512.61it/s]
# 100%|██████████| 76533/76533 [00:14<00:00, 5324.70it/s]
# 100%|██████████| 76533/76533 [00:17<00:00, 4374.68it/s]
# 100%|██████████| 76533/76533 [00:17<00:00, 4252.37it/s]
# 100%|██████████| 76533/76533 [00:18<00:00, 4190.38it/s]
# 100%|██████████| 76533/76533 [00:18<00:00, 4067.44it/s]
# 100%|██████████| 76533/76533 [00:19<00:00, 3970.41it/s]
# 100%|██████████| 76533/76533 [00:22<00:00, 3364.78it/s]
# 100%|██████████| 76533/76533 [00:27<00:00, 2780.80it/s]
# saving data
# done

# %%
@lru_cache(maxsize=total_events)
def process_tweets_subset(tweet_ids, event_id):
    all_tweets = get_tweets()
    sub_tweets = [t for t in all_tweets if str(t['_id']) in tweet_ids]
    
    representatives = get_representatives(event_id)

    _info("processing tweets")

    # rep_tweet: repr_id => tweet
    rep_tweet = dict()
    for t in tqdm(sub_tweets):
        rep_tweet[t['representative']] = t

    # repr_ids: {repr_id} // this event
    repr_ids = set([r['_id'] for r in representatives])

    # tweets_this_event: [tweet]
    tweets_this_event_ = [t for r, t in rep_tweet.items() if r in repr_ids]
    tweets_this_event = []
    
    # filter out tweets wo expanded urls
    for t in tweets_this_event_:
        e_u = t['expanded_urls']
        if all(u is not None for u in e_u):
            tweets_this_event.append(t)    

    tweets_tokens = dict()
    all_tokens = set()
    for tweet, doc in tqdm(zip(tweets_this_event, nlp.pipe([_t['text'] for _t in tweets_this_event],
                                                           n_threads=8,
                                                           batch_size=1024)),
                           total=len(tweets_this_event)):

        tokens = frozenset([token.lower_
                            for token in doc
                            if token.lower_ not in stopwords.words('english') and token.lower_ in ft_comp])

        if tokens and tokens not in all_tokens:
            tweets_tokens[str(tweet['_id'])] = tokens
            all_tokens.add(tokens)

    return tweets_tokens

# %%
#### MMR

lambda_ = 0.6
_1_lambda_ = 1 - lambda_

files = list(data_path.glob('event_*-topic_*-bm25_tweetid_score.txt'))

for f_0 in files:
    # f_0 = files[1]

    _, e_id, t_id, _, _ = f_0.name.split('_')
    event_id = e_id.split('-')[0]
    topic_id = t_id.split('-')[0]

    with f_0.open('r') as f:
        ranked_tweets_ = list((line[:-1].split('\t')[0], float(line[:-1].split('\t')[1])) for line in f)

    ranked_tweets = sorted(ranked_tweets_, key=itemgetter(1), reverse=True)    
    tweets = [t for t, _ in ranked_tweets]
    tweets_tokens = process_tweets_subset(frozenset(tweets), event_id)

    n_docs = len(tweets_tokens)
    tweet_vectors = np.array([np.mean([ft_comp[token] for token in tokens], axis=0) for _, tokens in tweets_tokens.items()])
    norm_vectors = tweet_vectors / norm(tweet_vectors)

    all_topics_this_event, _ = get_topics(event_id)
    this_topic = None
    for t in all_topics_this_event:
        if str(t['_id']) == topic_id:
            this_topic = t
            break

    query_keywords = frozenset(expand_query([t['keywords']])[0])
    query = np.mean([ft_comp[token] for token in query_keywords if token in ft_comp], axis=0)
    doc_q_sim = (norm_vectors).dot(query) * lambda_

    @lru_cache(maxsize=2**20)
    @jit
    def sim_c(doc_x, doc_y):
        return norm_vectors[doc_x].dot(norm_vectors[doc_y].T)

    @jit
    def score(doc_x, selected):
        max_sim = 0
        if selected - {doc_x}:
            for doc_y in selected - {doc_x}:
                sim = sim_c(doc_x, doc_y)
                if sim > max_sim:
                    max_sim = sim

        return doc_q_sim[doc_x] - _1_lambda_ * max_sim

    def mmr2(docs):
        selected = set()

        while selected != set(docs):
            remaining = set(docs) - selected

            max_score = 0
            next_selected = None
            for r in remaining:
                sc = score(r, frozenset(selected))
                if sc > max_score:
                    max_score = sc
                    next_selected = r

            selected.add(next_selected)
            yield next_selected

    tweets = [tweet_id for tweet_id, rank in ranked_tweets][:min(len(ranked_tweets), 1000)]

    print(this_topic['topic_name'])
    f_name = f'event_{event_id}-topic_{topic_id}-tweet_ids_sorted_mmr.txt'
    with (data_path / Path(f_name)).open('w') as f:
        for cnt, i in enumerate(mmr2(range(len(tweets)))):
            _id = tweets[i]
            # text = ' '.join(sorted(tweets_tokens[_id]))
            # print(cnt, text, sep="\t")
            f.write(f'{_id}\n')
# Out:
# 2018-07-06 16:26:40,964 : getting representatives
# 2018-07-06 16:26:41,210 : processing tweets
# 100%|██████████| 6993/6993 [00:00<00:00, 1172292.88it/s]
# 100%|██████████| 6993/6993 [00:26<00:00, 266.15it/s]
# 2018-07-06 16:27:07,761 : getting topics
# Police under investigation
# 2018-07-06 16:28:44,524 : getting representatives
# 2018-07-06 16:28:44,921 : processing tweets
# 100%|██████████| 232/232 [00:00<00:00, 542709.72it/s]
# 100%|██████████| 232/232 [00:00<00:00, 280.84it/s]
# 2018-07-06 16:28:45,802 : getting topics
# Humanitarian crisis
# 2018-07-06 16:28:48,124 : processing tweets
# 100%|██████████| 22075/22075 [00:00<00:00, 1260644.02it/s]
# 100%|██████████| 22075/22075 [01:17<00:00, 285.28it/s]
# Rescue of people
# 2018-07-06 16:31:42,910 : processing tweets
# 100%|██████████| 621/621 [00:00<00:00, 771523.34it/s]
# 100%|██████████| 621/621 [00:02<00:00, 270.93it/s]
# Oscar Pistorius removes his prosthesis
# 2018-07-06 16:32:09,115 : processing tweets
# 100%|██████████| 28876/28876 [00:00<00:00, 1269280.26it/s]
# 100%|██████████| 28876/28876 [01:35<00:00, 301.70it/s]
# Death tolls
# 2018-07-06 16:35:26,190 : processing tweets
# 100%|██████████| 4316/4316 [00:00<00:00, 1210715.36it/s]

#             'valentine',
#             'year'}),
#  '5b17172fda870923dcb0e61c': frozenset({'amp',
#             'broken',
#             'killed',
#             'message',
#             'oscar',
#             'pistorius',
#             'posted',
#             'reeva',
#             'shot',
#             'silence',
#             'website',
#             'year'}),
#  '5b17172fda870923dcb0e620': frozenset({"'s",
#             'day',
#             'pistorius',
#             'reeva',
#             'remembers',
#             'valentine'}),
#  '5b17172fda870923dcb0e62a': frozenset({"'s",
#             '4',
#             'anniversary',
#             'channel',
#             'first',
#             'google',
#             'news',
#             'pistorius',
#             'reeva',
#             'shooting',
#             'sorrow',
#             'viral'}),
#  '5b17172fda870923dcb0e634': frozenset({"'s",
#             'accident',
#             'day',
#             'devastating',
#             'girlfriend',
#             'killing',
#             'last',
#             'oscar',
#             'pistorius',
#             'reeva',
#             'steenkamp',
#             'valentine'}),
#  '5b17172fda870923dcb0e644': frozenset({"'s",
#             '2',
#             'attend',
#             'mom',
#             'oscar',
#             'pistorius',
#             'read',
#             'reeva',
#             'trial'}),
#  '5b17172fda870923dcb0e64c': frozenset({'#pistorius',
#             '#southafrica',
#             "'s",
#             'makes',
#             'oscar',
#             'reeva',
#             'shooting',
#             'sorrow',
#             'statement',
#             'steenkamp'}),
#  '5b17172fda870923dcb0e668': frozenset({"'s",
#             'amp',
#             'consumes',
#             'death',
#             'girlfriend',
#             'oscar',
#             'pain',
#             'pistorius',
#             'reeva',
#             'sadness',
#             'since',
#             'sorrow',
#             'steenkamp',
#             'year'}),
#  '5b17172fda870923dcb0e675': frozenset({"'s",
#             'accident',
#             'breaks',
#             'day',
#             'death',
#             'devastating',
#             'news',
#             'one',
#             'oscar',
#             'pistorius',
#             'reeva',
#             'silence',
#             'steenkamp',
#             'valentine',
#             'year'}),
#  '5b17172fda870923dcb0e679': frozenset({"'s",
#             'cheeky',
#             'day',
#             'lol',
#             'pistorius',
#             'reeva',
#             'remembers',
#             'valentine'}),
#  '5b17172fda870923dcb0e67b': frozenset({"'s",
#             'accident',
#             'breaks',
#             'day',
#             'death',
#             'devastating',
#             'one',
#             'oscar',
#             'pistorius',
#             'reeva',
#             'silence',
#             'steenkamp',
#             'valentine',
#             'year'}),
#  '5b17172fda870923dcb0e67d': frozenset({"'s",
#             'character',
#             'find',
#             'interesting',
#             'nothing',
#             'personality',
#             'pistorius',
#             'reeva',
#             'statement',
#             'tells',
#             'today',
#             'us'}),
#  '5b17172fda870923dcb0e684': frozenset({"'s",
#             'anniversary',
#             'consumed',
#             'death',
#             'news',
#             'oscar',
#             'overnight',
#             'pistorius',
#             'reeva',
#             'said',
#             'sorrow',
#             'steenkamp'}),
#  '5b17172fda870923dcb0e68d': frozenset({"'s",
#             'believes',
#             'case',
#             'cop',
#             'dead',
#             'ex',
#             'oscar',
#             'pistorius',
#             'reeva',
#             'shot',
#             'since',
#             'state',
#             'steenkamp&gt',
#             'tight',
#             'year'}),
#  '5b17172fda870923dcb0e68f': frozenset({"'s",
#             'aaand',
#             'ago',
#             'care',
#             'come',
#             'family',
#             'friends',
#             'happened',
#             'jokes',
#             'like',
#             'oscar',
#             'pistorius',
#             'reeva',
#             'right',
#             'whole',
#             'year'}),
#  '5b17172fda870923dcb0e6a3': frozenset({"'s",
#             'day',
#             'dead',
#             'ghost',
#             'oscar',
#             'pistorius',
#             'reeva',
#             'shot',
#             'since',
#             'steenkamp&gt',
#             'valentine',
#             'year'}),
#  '5b17172fda870923dcb0e6d0': frozenset({"'s",
#             'anniversary',
#             'death',
#             'gt;&gt',
#             'oscar',
#             'read',
#             'reeva',
#             'statement'}),
#  '5b17172fda870923dcb0e6f2': frozenset({"'s",
#             'death',
#             'expresses',
#             'grief',
#             'oscar',
#             'pistorius',
#             'reeva',
#             'steenkamp'}),
#  '5b17172fda870923dcb0e6f4': frozenset({"'s",
#             'act',
#             'death',
#             'expresses',
#             'grief',
#             'oscar',
#             'pistorius',
#             'reeva',
#             'steenkamp'}),
#  '5b17172fda870923dcb0e6ff': frozenset({"'s",
#             'anniversary',
#             'consumed',
#             'death',
#             'first',
#             'loss',
#             'model',
#             'paralympi',
#             'pistorius',
#             'reeva',
#             'says',
#             'sorrow'}),
#  '5b17172fda870923dcb0e702': frozenset({'#pistorius',
#             '#steenkamp',
#             "'s",
#             '1',
#             'anniversary',
#             'death',
#             'message',
#             'oscar',
#             'posted',
#             'reeva',
#             'website',
#             'year'}),
#  '5b17172fda870923dcb0e706': frozenset({"'s",
#             'aw',
#             'death',
#             'expresses',
#             'grief',
#             'oscar',
#             'pistorius',
#             'reeva',
#             'steenkamp'}),
#  '5b17172fda870923dcb0e70c': frozenset({"'s",
#             'anniversary',
#             'consumed',
#             'death',
#             'first',
#             'loss',
#             'model',
#             'pistorius',
#             'reeva',
#             'says',
#             'sorrow'}),
#  '5b17172fda870923dcb0e710': frozenset({"'s",
#             'death',
#             'expresses',
#             'grief',
#             'oscar',
#             'pistorius',
#             'pr',
#             'reeva',
#             'rt',
#             'steenkamp',
#             'team'}),
#  '5b17172fda870923dcb0e71d': frozenset({"'s",
#             'coming',
#             'easy',
#             'family',
#             'fast',
#             'forget',
#             'guys',
#             'jokes',
#             "n't",
#             'oscar',
#             'pistorius',
#             'place',
#             'reeva',
#             'shame',
#             'take',
#             'thick',
#             'time',
#             'wow'}),
#  '5b17172fda870923dcb0e72a': frozenset({'#pistorius',
#             '1',
#             'consumes',
#             'girlfriend',
#             'pain',
#             'reeva',
#             'releases',
#             'sadness',
#             'says',
#             'shooting',
#             'sorrow',
#             'statement',
#             'website',
#             'year'}),
#  '5b17172fda870923dcb0e72c': frozenset({'#celebrity',
#             "'s",
#             'anniversary',
#             'death',
#             'oscar',
#             'pistorius',
#             'reeva',
#             'releases',
#             'statement',
#             'steenkamp'}),
#  '5b17172fda870923dcb0e741': frozenset({"'s",
#             'dead',
#             'make',
#             'nothing',
#             'oscar',
#             'pistorius',
#             'reeva',
#             'right',
#             'shot',
#             'since',
#             'steenkamp&gt',
#             'us',
#             'year'}),
#  '5b17172fda870923dcb0e74c': frozenset({"'s",
#             '25',
#             'death',
#             'leaders',
#             'least',
#             'oscar',
#             'pistorius',
#             'reeva',
#             'serve',
#             'speaking',
#             'tm',
#             'want',
#             'years'}),
#  '5b17172fda870923dcb0e751': frozenset({'accused',
#             'death',
#             'incident',
#             'murder',
#             'oscar',
#             'paralympian',
#             'pistorius',
#             'pretoria',
#             'reevas',
#             'says',
#             'tragic'}),
#  '5b17172fda870923dcb0e753': frozenset({"'s",
#             'death',
#             'pistorius',
#             'reeva',
#             'sorrow'}),
#  '5b17172fda870923dcb0e75b': frozenset({"'s",
#             '3',
#             'day',
#             'makes',
#             'march',
#             'one',
#             'pistorius',
#             'reeva',
#             'stand',
#             'statement',
#             'trial',
#             'valentine',
#             'year'}),
#  '5b17172fda870923dcb0e76d': frozenset({"'s",
#             'breaks',
#             'death',
#             'heart',
#             'pistorius',
#             'reeva',
#             'rt',
#             'silence',
#             'since',
#             'tweet',
#             'words',
#             'year'}),
#  '5b17172fda870923dcb0e770': frozenset({'#worldnews',
#             "'s",
#             'day',
#             'pistorius',
#             'reeva',
#             'remembers',
#             'valentine'}),
#  '5b17172fda870923dcb0e794': frozenset({"'s",
#             'amp',
#             'consumes',
#             'death',
#             'gf',
#             'oscar',
#             'pain',
#             'pistorius',
#             'reeva',
#             'sadness',
#             'since',
#             'sorrow',
#             'steenkamp',
#             'year'}),
#  '5b17172fda870923dcb0e7a1': frozenset({'#olympics',
#             '#scandal',
#             "'s",
#             'anniversary',
#             'death',
#             'oscar',
#             'pistorius',
#             'reeva',
#             'releases',
#             'statement',
#             'steenkamp'}),
#  '5b17172fda870923dcb0e7a7': frozenset({'death',
#             'imagine',
#             'incident',
#             'pistorius',
#             'reevas',
#             'rt',
#             'says',
#             'tragic',
#             'yhoooo'}),
#  '5b17172fda870923dcb0e7ac': frozenset({"'s",
#             'consumed',
#             'exactly',
#             'one',
#             'oscar',
#             'pistorius',
#             'reeva',
#             'sorrow',
#             'steenkamp',
#             'year'}),
#  '5b17172fda870923dcb0e7ae': frozenset({"'s",
#             'anniversary',
#             'breaks',
#             'girlfriend',
#             'oscar',
#             'pistorius',
#             'silence',
#             'slaying'}),
#  '5b17172fda870923dcb0e7b4': frozenset({'death',
#             'imagine',
#             'incident',
#             'pistorius',
#             'reevas',
#             'rt',
#             'says',
#             'tragic'}),
#  '5b17172fda870923dcb0e7e2': frozenset({"'s",
#             'ago',
#             'around',
#             'bird',
#             'death',
#             'free',
#             'girlfriend',
#             'jealous',
#             'oscar',
#             'pistorius',
#             'rage',
#             'reeva',
#             'shot',
#             'steenkamp',
#             'still',
#             'today',
#             'walking',
#             'year'}),
#  '5b17172fda870923dcb0e7fd': frozenset({"'s",
#             'coming',
#             'easy',
#             'family',
#             'fast',
#             'forget',
#             'guys',
#             'jokes',
#             "n't",
#             'oscar',
#             'pistorius',
#             'place',
#             'reeva',
#             'shame',
#             'take',
#             'thick',
#             'time'}),
#  '5b17172fda870923dcb0e806': frozenset({"'s",
#             'breaking',
#             'death',
#             'incident',
#             'news',
#             'pistorius',
#             'reeva',
#             'sa',
#             'says',
#             'tragic',
#             '|'}),
#  '5b17172fda870923dcb0e80f': frozenset({"'s",
#             '1',
#             'clyde',
#             'day',
#             'pistorius',
#             'reeva',
#             'remembers',
#             'valentine',
#             '|'}),
#  '5b17172fda870923dcb0e813': frozenset({"'s",
#             'anniversary',
#             'death',
#             'gt;&gt',
#             'oscar',
#             'read',
#             'reeva',
#             'rt',
#             'statement'}),
#  '5b17172fda870923dcb0e823': frozenset({"'s",
#             'families',
#             'oscar',
#             'statement',
#             'thoughts',
#             'today'}),
#  '5b17172fda870923dcb0e82b': frozenset({"'s",
#             'consumed',
#             'death',
#             'one',
#             'oscar',
#             'pistorius',
#             'reeva',
#             'sorrow',
#             'steenkamp',
#             'year'}),
#  '5b17172fda870923dcb0e839': frozenset({"'s",
#             'anniversary',
#             'broken',
#             'death',
#             'finally',
#             'oscar',
#             'pistorius',
#             'read',
#             'reeva',
#             'silence'}),
#  '5b17172fda870923dcb0e85c': frozenset({"'s",
#             'expressed',
#             'fatal',
#             'grief',
#             'oscar',
#             'pistorius',
#             'reeva',
#             'shooting',
#             'since',
#             'statement',
#             'steenkamp',
#             'year'}),
#  '5b17172fda870923dcb0e86c': frozenset({"'s",
#             '1st',
#             'anniversary',
#             'death',
#             'girlfriend',
#             'issued',
#             'oscar',
#             'paralympian',
#             'pistorius',
#             'reeva',
#             'statement',
#             'steenkamp'}),
#  '5b17172fda870923dcb0e876': frozenset({'ago',
#             'amp',
#             'girlfriend',
#             'killed',
#             'news',
#             'oscar',
#             'pistorius',
#             'r.i.p',
#             'reeva',
#             'shot',
#             'steenkamp',
#             'today',
#             'woke',
#             'world',
#             'year'}),
#  '5b17172fda870923dcb0e87a': frozenset({"'s",
#             'changed',
#             'day',
#             'died',
#             'exactly',
#             'family',
#             'forever',
#             'lives',
#             'pistorius',
#             'reeva',
#             'steenkamp',
#             'today',
#             'valentine',
#             'year'}),
#  '5b17172fda870923dcb0e892': frozenset({"'s",
#             'boyfrnd',
#             'day',
#             'dead',
#             'famous',
#             'marks',
#             'oscar',
#             'pistorius',
#             'rebecca',
#             'reeva',
#             'shot',
#             'since',
#             'steenkamp',
#             'valentine',
#             'world',
#             'year'}),
#  '5b17172fda870923dcb0e8a0': frozenset({'#oscarpistorius',
#             '#pistorius',
#             '#sa',
#             'accused',
#             'death',
#             'incident',
#             'really',
#             'reevas',
#             'says',
#             'tragic',
#             'wonder'}),
#  '5b17172fda870923dcb0e8a2': frozenset({"'s",
#             'death',
#             'pistorius',
#             'reeva',
#             'say',
#             'solved',
#             'tragic'}),
#  '5b17172fda870923dcb0e8a5': frozenset({'death',
#             'incident',
#             'pistorius',
#             'reevas',
#             'says',
#             'tragic'}),
#  '5b17172fda870923dcb0e8a7': frozenset({'hear',
#             "n't",
#             'pistorius',
#             'probably',
#             'reeva',
#             'rt',
#             'says',
#             'scream'}),
#  '5b17172fda870923dcb0e8a9': frozenset({"'s",
#             'consumed',
#             'death',
#             'oscar',
#             'ov',
#             'paralympic',
#             'pistorius',
#             'reeva',
#             'said',
#             'sorrow',
#             'star'}),
#  '5b17172fda870923dcb0e8ab': frozenset({'#pistorius',
#             "'s",
#             'breaking',
#             'death',
#             'incident',
#             'news',
#             'reeva',
#             'sa',
#             'says',
#             'tragic',
#             '|'}),
#  '5b17172fda870923dcb0e8ba': frozenset({"'s",
#             'pistorius',
#             'reeva',
#             'remembers',
#             'valentine'}),
#  '5b17172fda870923dcb0e8c4': frozenset({"'s",
#             'cry',
#             'fav',
#             'justin',
#             'oscar',
#             'pistorius',
#             'reeva',
#             'song',
#             'timberlake'}),
#  '5b17172fda870923dcb0e8c9': frozenset({'amp',
#             'conviction',
#             'day',
#             'murdered',
#             'reeva',
#             'sad',
#             'steenkamp',
#             'still',
#             'year'}),
#  '5b17172fda870923dcb0e8e4': frozenset({"'s",
#             '1-year',
#             'anniversary',
#             'complete',
#             'death',
#             'loss',
#             'oscar',
#             'pistorius',
#             'reeva',
#             'steenkamp',
#             'trauma'}),
#  '5b17172fda870923dcb0e8f6': frozenset({'#breakingnews',
#             "'s",
#             '1-year',
#             'anniversary',
#             'com',
#             'death',
#             'loss',
#             'oscar',
#             'pistorius',
#             'reeva',
#             'steenkamp'}),
#  '5b17172fda870923dcb0e8f9': frozenset({"'s",
#             'closure',
#             'girlfriend',
#             'oscar',
#             'parents',
#             'pistorius',
#             'provide',
#             'reeva',
#             'said',
#             'slain',
#             'steenkamp',
#             'trial',
#             'tuesday',
#             'upcoming',
#             'wanted'}),
#  '5b17172fda870923dcb0e8fb': frozenset({"'s",
#             'day',
#             'girlfriend',
#             'pens',
#             'pistorius',
#             'shot',
#             'tribute',
#             'valentine',
#             'via'}),
#  '5b17172fda870923dcb0e903': frozenset({"'s",
#             'breaks',
#             'day',
#             'death',
#             'devastating',
#             'one',
#             'oscar',
#             'pistorius',
#             'reeva',
#             'silence',
#             'steenkamp',
#             'valentine',
#             'year'}),
#  '5b17172fda870923dcb0e90d': frozenset({"'s",
#             'anniversary',
#             'first',
#             'loss',
#             'pistorius',
#             'reeva',
#             'shooting',
#             'sorrow',
#             'wil'}),
#  '5b17172fda870923dcb0e90f': frozenset({"'s",
#             '1-year',
#             'anniversary',
#             'breakingnews',
#             'death',
#             'loss',
#             'oscar',
#             'pistorius',
#             'reeva',
#             'steenkamp'}),
#  '5b17172fda870923dcb0e911': frozenset({"'s",
#             'breaks',
#             'day',
#             'death',
#             'devasta',
#             'one',
#             'oscar',
#             'pistorius',
#             'reeva',
#             'silence',
#             'steenkamp',
#             'valentine',
#             'year'}),
#  '5b17172fda870923dcb0e913': frozenset({"'s",
#             'breaks',
#             'day',
#             'death',
#             'devastati',
#             'indyworld',
#             'one',
#             'oscar',
#             'pistorius',
#             'reeva',
#             'silence',
#             'steenkamp',
#             'valentine',
#             'year'}),
#  '5b17172fda870923dcb0e924': frozenset({"'s",
#             'day',
#             'r.i.p',
#             'reeva',
#             'remembers',
#             'valentine'}),
#  '5b17172fda870923dcb0e92a': frozenset({'#breakingnews',
#             "'s",
#             '1-year',
#             'anniversary',
#             'death',
#             'loss',
#             'oscar',
#             'pistorius',
#             'reeva',
#             'steenkamp'}),
#  '5b17172fda870923dcb0e936': frozenset({"'s",
#             'african',
#             'anniversary',
#             'breaks',
#             'day',
#             'death',
#             'girlfriend',
#             'oscar',
#             'paralympic',
#             'pistorius',
#             'silence',
#             'south',
#             'valentine'}),
#  '5b17172fda870923dcb0e938': frozenset({'#news',
#             "'s",
#             '2013',
#             'cape',
#             'death',
#             'expressed',
#             'girlfriend',
#             'mr.',
#             'murder',
#             'pistorius',
#             'reeva',
#             'residence',
#             'sadness',
#             'stands',
#             'trial'}),
#  '5b17172fda870923dcb0e93a': frozenset({'1yr',
#             'aiming',
#             'amp',
#             'empathy',
#             'public',
#             'shooting',
#             'still',
#             'wife'}),
#  '5b17172fda870923dcb0e953': frozenset({"'ll",
#             "'s",
#             'accident',
#             'breaks',
#             'day',
#             'devastating',
#             'hmm',
#             'one',
#             'pistorius',
#             'reeva',
#             'see',
#             'shooting',
#             'silence',
#             'valentine',
#             'year'}),
#  '5b17172fda870923dcb0e95d': frozenset({"'s",
#             '4',
#             'anniversary',
#             'channel',
#             'first',
#             'news',
#             'pistorius',
#             'reeva',
#             'shooting',
#             'sorrow'}),
#  '5b17172fda870923dcb0e960': frozenset({'back',
#             'death',
#             'look',
#             'one',
#             'oscar',
#             'pistorius',
#             'reeva',
#             'releases',
#             'today',
#             'tragedy',
#             'words',
#             'year'}),
#  '5b17172fda870923dcb0e96b': frozenset({"'s",
#             'anniversary',
#             'day',
#             'death',
#             'oscar',
#             'pistorius',
#             'posts',
#             'reeva',
#             'steenkamp',
#             'tribute',
#             'valentine'}),
#  '5b17172fda870923dcb0e971': frozenset({"'s",
#             'already',
#             'believe',
#             'ca',
#             "n't",
#             'oscar',
#             'pistorius',
#             'reeva',
#             'shot',
#             'since',
#             'year'}),
#  '5b17172fda870923dcb0e97f': frozenset({"'s",
#             'day',
#             'issued',
#             'oscar',
#             'pistorius',
#             'reeva',
#             'remembers',
#             'saying',
#             'statement',
#             'valentine',
#             'valentines'}),
#  '5b17172fda870923dcb0e9cf': frozenset({"'s",
#             'end',
#             'family',
#             'frenzy',
#             'media',
#             'oscar',
#             'pistorius',
#             'plead',
#             'trial',
#             'worldnewsapp'}),
#  '5b17172fda870923dcb0e9d9': frozenset({'back',
#             'betting',
#             'company',
#             'deal',
#             'metro',
#             'money',
#             'offers',
#             'oscar',
#             'pistorius',
#             'trial',
#             'walks'}),
#  '5b17172fda870923dcb0e9e8': frozenset({"'ve",
#             'address',
#             'another',
#             'become',
#             'blooded',
#             'boss',
#             'cake',
#             'cold',
#             'life',
#             'oscar',
#             'pistorius',
#             'real',
#             'reality',
#             'show',
#             'thing',
#             'tv'}),
#  '5b17172fda870923dcb0e9f7': frozenset({"'re",
#             "'ve",
#             'amp',
#             'bereaved',
#             'bet',
#             'family',
#             'got',
#             'hey',
#             'listed',
#             'novelty',
#             'reeva',
#             'shameless',
#             'steenkamp',
#             'trial'}),
#  '5b17172fda870923dcb0ea72': frozenset({'back',
#             'money',
#             'murder',
#             'oscar',
#             'pistorius',
#             'trial',
#             'walks'}),
#  '5b17172fda870923dcb0ea85': frozenset({"'s",
#             '2',
#             'murder',
#             'please',
#             'reduced',
#             'sport',
#             'stop',
#             'woman',
#             'young'}),
#  '5b17172fda870923dcb0ea95': frozenset({'#reevasteenkamp',
#             '#vaw',
#             "'s",
#             'amp',
#             'capitalising',
#             'murder',
#             'rt',
#             'sign',
#             'tolerated'}),
#  '5b17172fda870923dcb0eaa8': frozenset({'case',
#             'earlier',
#             'link',
#             "n't",
#             'paddypower',
#             'petition',
#             'working'}),
#  '5b17172fda870923dcb0eaac': frozenset({"'s",
#             'answers',
#             'collide',
#             'come',
#             'day',
#             'hopefully',
#             'need',
#             'oscar',
#             'oscars',
#             'people',
#             'pistorius',
#             'today',
#             'tomorrow',
#             'truth'}),
#  '5b17172fda870923dcb0eabb': frozenset({"'s", 'may', 'petition', 'seen'}),
#  '5b17172fda870923dcb0eae9': frozenset({'another',
#             'around',
#             'drama',
#             'forget',
#             'oscar',
#             'oscars',
#             'real',
#             'tomorrow',
#             'tonight',
#             'unfolds'}),
#  '5b17172fda870923dcb0eaf7': frozenset({"'m",
#             "'s",
#             'already',
#             'bored',
#             'even',
#             'oscar',
#             'pistorius',
#             'started',
#             'trial',
#             'yet'}),
#  '5b17172fda870923dcb0eb25': frozenset({'#justice',
#             "'s",
#             'coming',
#             'gets',
#             'hoping',
#             'oscar',
#             'pistorius',
#             'really',
#             'trial',
#             'week'}),
#  '5b17172fda870923dcb0eb3a': frozenset({"'ll",
#             'family',
#             'focus',
#             'oscar',
#             'pistorius',
#             'says',
#             'trial'}),
#  '5b17172fda870923dcb0eb67': frozenset({'#shameful',
#             "'s",
#             'betting',
#             'murder',
#             'really',
#             'woman'}),
#  '5b17172fda870923dcb0eb75': frozenset({"'s",
#             'case',
#             'country',
#             'goes',
#             'name',
#             'ooh',
#             'oscar',
#             'pistorius',
#             'starts',
#             'tomorrow'}),
#  '5b17172fda870923dcb0ebb8': frozenset({'#13statefacts',
#             "'s",
#             'case',
#             'oscar',
#             'pistorius',
#             'running',
#             'state',
#             'using'}),
#  '5b17172fda870923dcb0ebc5': frozenset({"'s",
#             'becomes',
#             'disgrace',
#             'game',
#             'murder',
#             'nothing',
#             'odds',
#             'protest',
#             'woman',
#             'young'}),
#  '5b17172fda870923dcb0ebd9': frozenset({"'s",
#             'believe',
#             'day',
#             'girlfriend',
#             'loy',
#             'machedo',
#             'mistook',
#             'oscar',
#             'pistorius',
#             'question',
#             'says'}),
#  '5b17172fda870923dcb0ebdc': frozenset({"'s",
#             'even',
#             'excuse',
#             'girlfriend',
#             'got',
#             'oscar',
#             'pistorius'}),
#  '5b17172fda870923dcb0ebf0': frozenset({'#bladerunner',
#             "'s",
#             'africa',
#             'century',
#             'pistorius',
#             'south',
#             'trial'}),
#  '5b17172fda870923dcb0ec0b': frozenset({'#dateline',
#             "'s",
#             'catch',
#             'friday',
#             'miss'}),
#  '5b17172fda870923dcb0ec0d': frozenset({'#newslocker',
#             "'s",
#             'blade',
#             'decide',
#             'fate',
#             'key',
#             'murder',
#             'oscar',
#             'pistorius',
#             'players',
#             'runner',
#             'trial'}),
#  '5b17172fda870923dcb0ec1c': frozenset({"'s",
#             'awards',
#             'folks',
#             'get',
#             'let',
#             'mixed',
#             'oscar',
#             'pistorius',
#             'tomorrow',
#             'tonight'}),
#  '5b17172fda870923dcb0ec29': frozenset({"'s",
#             'blade',
#             'decide',
#             'fate',
#             'key',
#             'murder',
#             'oscar',
#             'paralympian',
#             'pistorius',
#             'players',
#             'runner',
#             'trial'}),
#  '5b17172fda870923dcb0ec37': frozenset({'bloodd',
#             'burglar',
#             'cold',
#             'door',
#             'fired',
#             'gf',
#             'lockd',
#             'murder',
#             'pistorius',
#             'says',
#             'state',
#             'thru'}),
#  '5b17172fda870923dcb0ec5b': frozenset({"'s",
#             'africa',
#             'case',
#             'hands',
#             'jury',
#             'lies',
#             'man',
#             "n't",
#             'one',
#             'oscar',
#             'pistorius',
#             'south',
#             'system'}),
#  '5b17172fda870923dcb0ec5d': frozenset({"'s",
#             'oscar',
#             'pistorius',
#             'stat',
#             'trial',
#             'witnesses',
#             'yolii_freszh'}),
#  '5b17172fda870923dcb0ec75': frozenset({'back',
#             'betting',
#             'disgusting',
#             'firm',
#             'found',
#             'guilty',
#             'money',
#             'offering',
#             'paddy',
#             'pistorius',
#             'power',
#             'repugnant'}),
#  '5b17172fda870923dcb0ecbe': frozenset({"'s",
#             'africa',
#             'legal',
#             'oscar',
#             'pistorius',
#             'south',
#             'spotlight',
#             'system',
#             'trial'}),
#  '5b17172fda870923dcb0eccb': frozenset({'amp',
#             'bets',
#             'feel',
#             'free',
#             'obnoxious',
#             'outcome',
#             'pretorius',
#             'rt',
#             'sick',
#             'tell',
#             'trial'}),
#  '5b17172fda870923dcb0eccf': frozenset({"'s",
#             '-africa',
#             'become',
#             'black',
#             'children',
#             'circus',
#             'many',
#             'media',
#             'murdered',
#             'oscar',
#             'pistorius',
#             'raped',
#             'sa',
#             'sickening',
#             'woes',
#             'women'}),
#  '5b17172fda870923dcb0ecd1': frozenset({'amp',
#             'cr7',
#             'glasses',
#             'maybe',
#             'need',
#             'oscar',
#             'pistorius',
#             'wear'}),
#  '5b17172fda870923dcb0ecd9': frozenset({'#controversial',
#             'back',
#             'money',
#             'murder',
#             'oscar',
#             'pistorius',
#             'trial',
#             'walks'}),
#  '5b17172fda870923dcb0ecdb': frozenset({"'s",
#             '=',
#             'case',
#             'explore',
#             'oscar',
#             'pistorius',
#             'sad',
#             'side',
#             'trial'}),
#  '5b17172fda870923dcb0ece8': frozenset({'ad',
#             'amp',
#             'bets',
#             'domestic',
#             'donate',
#             'fighting',
#             'offering',
#             'paddy',
#             'pistorius',
#             'power',
#             'remove',
#             'trial',
#             'urge',
#             'via',
#             'violence'}),
#  '5b17172fda870923dcb0ecec': frozenset({"'s",
#             'excited',
#             'oscar',
#             'pistorius',
#             'teenager',
#             'trial'}),
#  '5b17172fda870923dcb0ed00': frozenset({'back',
#             'money',
#             'murder',
#             'oscar',
#             'paddy',
#             'pistorius',
#             'power',
#             'trial',
#             'walks'}),
#  '5b17172fda870923dcb0ed1e': frozenset({"'s",
#             'actor',
#             'best',
#             'get',
#             'heard',
#             'jst',
#             'late',
#             'oscar',
#             'oscars',
#             'performance',
#             'pistorius',
#             'tonight',
#             'wonder',
#             'wonderful'}),
#  '5b17172fda870923dcb0ed2f': frozenset({"'s",
#             'africa',
#             'biggest',
#             'display',
#             'murder',
#             'oscar',
#             'pistorius',
#             'problems',
#             'putting',
#             'south',
#             'trial'}),
#  '5b17172fda870923dcb0ed35': frozenset({"'s",
#             'already',
#             'case',
#             'coverage',
#             'dead',
#             'murder',
#             'mxm',
#             "n't",
#             'oscar',
#             'pistorius',
#             'reeva',
#             'sick',
#             'started',
#             'steenkamp'}),
#  '5b17172fda870923dcb0ed51': frozenset({"'s",
#             'also',
#             'away',
#             'cunt',
#             'done',
#             'forever',
#             'fucking',
#             'gets',
#             'hope',
#             'locked',
#             'opinion',
#             'oscar',
#             'pistorius',
#             'tut',
#             'tutorial'}),
#  '5b17172fda870923dcb0ed5d': frozenset({'back',
#             'bets',
#             'case',
#             'money',
#             'murder',
#             'offering',
#             'oscar',
#             'outrage',
#             'paddy',
#             'pistorius',
#             'power',
#             'prompts',
#             'walks'}),
#  '5b17172fda870923dcb0ed66': frozenset({"'s",
#             'africa',
#             'claiming',
#             'deserves',
#             'hero',
#             'killer',
#             'long',
#             'oscar',
#             'pistorius',
#             'prison',
#             'sentence',
#             'south'}),
#  '5b17172fda870923dcb0ed82': frozenset({"'s",
#             'begins',
#             'girlfriend',
#             'life',
#             'monday',
#             'murder',
#             'oscar',
#             'pistorius',
#             'spotlight',
#             'story',
#             'trial'}),
#  '5b17172fda870923dcb0ed84': frozenset({'back',
#             'independent',
#             'money',
#             'offering',
#             'oscar',
#             'outrage',
#             'paddy',
#             'pistorius',
#             'power',
#             'prompts'}),
#  '5b17172fda870923dcb0ed86': frozenset({"'s",
#             '1',
#             'another',
#             'awards',
#             'front',
#             'get',
#             'hours',
#             'international',
#             'morning',
#             'oscar',
#             'pages',
#             'pistorius',
#             'trial',
#             'wee'}),
#  '5b17172fda870923dcb0edc6': frozenset({"'s",
#             '-rolls',
#             'aaand',
#             'best',
#             'eyes-',
#             'facts',
#             'old',
#             'oscar',
#             'pistorius',
#             'repeated',
#             'saga',
#             'sensationalism',
#             'whole'}),
#  '5b17172fda870923dcb0edc8': frozenset({"'s",
#             'alone',
#             'follow',
#             'may',
#             'one',
#             'oscar',
#             'others',
#             'pistorius',
#             'road',
#             'walk'}),
#  '5b17172fda870923dcb0edcc': frozenset({"'s",
#             'case',
#             'get',
#             'let',
#             'oscar',
#             'pistorius',
#             'tonight'}),
#  '5b17172fda870923dcb0ede9': frozenset({'2',
#             'african',
#             'amp',
#             'dra',
#             'elections',
#             'happen',
#             'latter',
#             'oscar',
#             'pistorius',
#             'south',
#             'things',
#             'unfortunately',
#             'want'}),
#  '5b17172fda870923dcb0edeb': frozenset({"'s",
#             '107',
#             'ap',
#             'call',
#             'johannesburg',
#             'loo',
#             'named',
#             'oscar',
#             'pistorius',
#             'prosecutors',
#             'trial',
#             'witnesses'}),
#  '5b17172fda870923dcb0edfc': frozenset({"'s",
#             'oscar',
#             'pistorius',
#             'tomorrow',
#             'trial'}),
#  '5b17172fda870923dcb0ee16': frozenset({"'s",
#             'care',
#             'case',
#             'events',
#             'going',
#             'guess',
#             'important',
#             'makes',
#             'media',
#             "n't",
#             'news',
#             'oscar',
#             'pistorius',
#             'switch'}),
#  '5b17172fda870923dcb0ee31': frozenset({'6',
#             '6.30pm',
#             'amp',
#             'bring',
#             'ecr',
#             'evening',
#             'every',
#             'experts',
#             'insights',
#             'oscar',
#             'panel',
#             'pistorius',
#             'tomorrow',
#             'trial'}),
#  '5b17172fda870923dcb0ee45': frozenset({"'s",
#             'hell',
#             'laughing',
#             'oscar',
#             'pistorius',
#             'shooting',
#             'sunroof',
#             'thug'}),
#  '5b17172fda870923dcb0ee47': frozenset({"'s",
#             'case',
#             'gon',
#             'interesting',
#             'na',
#             'oscar',
#             'pistorius',
#             'televised',
#             'tomorrow'}),
#  '5b17172fda870923dcb0ee49': frozenset({"'s",
#             'case',
#             'couples',
#             'friends',
#             'oscar',
#             'pistorius',
#             'porn',
#             'reeva',
#             'rows',
#             'testify'}),
#  '5b17172fda870923dcb0ee6c': frozenset({"'s",
#             'begins',
#             'end',
#             'family',
#             'frenzy',
#             'media',
#             'oscar',
#             'pistorius',
#             'plead',
#             'trial'}),
#  '5b17172fda870923dcb0ee6e': frozenset({"'s",
#             'fine',
#             'informative',
#             'journalism',
#             'like',
#             'oscar',
#             'pistorius',
#             'reality',
#             'tv'}),
#  '5b17172fda870923dcb0ee74': frozenset({'#13statefacts',
#             "'s",
#             'case',
#             'oops',
#             'oscar',
#             'pistorius',
#             'really',
#             'rt',
#             'running',
#             'state',
#             'using'}),
#  '5b17172fda870923dcb0ee76': frozenset({'back',
#             'bets',
#             'c',
#             'indyworld',
#             'money',
#             'murder',
#             'offering',
#             'oscar',
#             'outrage',
#             'paddy',
#             'pistorius',
#             'power',
#             'prompts',
#             'walks'}),
#  '5b17172fda870923dcb0ee7d': frozenset({"'s",
#             'angle',
#             'blanche',
#             'carte',
#             'case',
#             'csi',
#             'episode',
#             'interesting',
#             'like',
#             'making',
#             'oscar',
#             'pistorius',
#             'rt',
#             'seem',
#             'tho'}),
#  '5b17172fda870923dcb0eea0': frozenset({'back',
#             'getty',
#             'images',
#             'independent',
#             'money',
#             'offering',
#             'oscar',
#             'outrage',
#             'paddy',
#             'pistorius',
#             'power',
#             'prompts'}),
#  '5b17172fda870923dcb0eea7': frozenset({"'s",
#             'arnold',
#             'oscar',
#             'pistorius',
#             'statement',
#             'uncle',
#             'update'}),
#  '5b17172fda870923dcb0eeb8': frozenset({"'s",
#             'breaking',
#             'hosting',
#             'news',
#             'oscar',
#             'oscars',
#             'pistorius',
#             'tonight'}),
#  '5b17172fda870923dcb0eebc': frozenset({'back',
#             'money',
#             'offering',
#             'oscar',
#             'outrage',
#             'paddy',
#             'pistorius',
#             'power',
#             'prompts'}),
#  '5b17172fda870923dcb0eebf': frozenset({'accents',
#             'american',
#             'amp',
#             'blanche',
#             'british',
#             'carte',
#             'case',
#             'csi',
#             'episode',
#             'like',
#             'making',
#             'oscar',
#             'pistorius',
#             'seem'}),
#  '5b17172fda870923dcb0eed2': frozenset({"'s",
#             'barton',
#             'bit',
#             'butting',
#             'calling',
#             'character',
#             'head',
#             'incident',
#             'joey',
#             'like',
#             'oj',
#             'oscar',
#             'pardew',
#             'pistorius',
#             'public',
#             'simpson',
#             'support',
#             'witness'}),
#  '5b17172fda870923dcb0eee4': frozenset({'blanche',
#             'carte',
#             'case',
#             'csi',
#             'episode',
#             'forensics',
#             'like',
#             'making',
#             'oscar',
#             'pistorius',
#             'seem',
#             'well',
#             'working'}),
#  '5b17172fda870923dcb0eee6': frozenset({'anger',
#             'back',
#             'bet',
#             'disgusting',
#             'loses',
#             'money',
#             'paddy',
#             'pistorius',
#             'plot',
#             'power',
#             'sparks',
#             'trial',
#             'via',
#             'walks'}),
#  '5b17172fda870923dcb0ef08': frozenset({'amp',
#             'back',
#             'gross',
#             'inappropriate',
#             'money',
#             'murder',
#             'oscar',
#             'pistorius',
#             'seriously',
#             'trial',
#             'walks'}),
#  '5b17172fda870923dcb0ef11': frozenset({"'s",
#             'already',
#             'anticipation',
#             'away',
#             'carried',
#             'drama',
#             'everyone',
#             'get',
#             'glued',
#             'let',
#             'oscar',
#             'pistorius',
#             'seats',
#             'start'}),
#  '5b17172fda870923dcb0ef1b': frozenset({"'s",
#             'access',
#             'app',
#             'blackberry',
#             'channel',
#             'dstv',
#             'news24',
#             'oscar',
#             'pistorius',
#             'sent',
#             'trial',
#             'via'}),
#  '5b17172fda870923dcb0ef26': frozenset({"'m",
#             "'s",
#             '100',
#             'already',
#             'making',
#             'millions',
#             'movie',
#             'oscar',
#             'pistorius',
#             'rt',
#             'someone',
#             'sure',
#             'talking',
#             'working'}),
#  '5b17172fda870923dcb0ef3f': frozenset({"'s",
#             'access',
#             'channel',
#             'dstv',
#             'oscar',
#             'pistorius',
#             'trial'}),
#  '5b17172fda870923dcb0ef44': frozenset({"'s",
#             'accused',
#             'fake',
#             'message',
#             'murder',
#             'oscar',
#             'pistorius',
#             'post',
#             'pr',
#             'says',
#             'team',
#             'thank'}),
#  '5b17172fda870923dcb0ef49': frozenset({'#13statefacts',
#             "'s",
#             'case',
#             'coming',
#             'know',
#             'need',
#             'oscar',
#             'pistorius',
#             'state'}),
#  '5b17172fda870923dcb0ef4b': frozenset({'11/8',
#             'back',
#             'bet',
#             'found',
#             'free',
#             'guilty',
#             'money',
#             'oscar',
#             'pistorius',
#             'risk',
#             'talk',
#             'walks'}),
#  '5b17172fda870923dcb0ef52': frozenset({"'s",
#             'believe',
#             'ca',
#             'circulate',
#             "n't",
#             'one',
#             'real',
#             'still',
#             'vultures',
#             'word'}),
#  '5b17172fda870923dcb0ef58': frozenset({"'s",
#             '199',
#             'access',
#             'channel',
#             'dstv',
#             'lol',
#             "n't",
#             'oscar',
#             'pistorius',
#             'press',
#             'remote',
#             'rt',
#             'trial'}),
#  '5b17172fda870923dcb0ef5a': frozenset({"'s",
#             'access',
#             'channel',
#             'dstv',
#             'oscar',
#             'pistorius',
#             'trial',
#             'via'}),
#  '5b17172fda870923dcb0ef60': frozenset({"'s",
#             'access',
#             'channel',
#             'dstv',
#             'hey',
#             'oscar',
#             'pistorius',
#             'really',
#             'trial',
#             'us',
#             'work'}),
#  '5b17172fda870923dcb0ef65': frozenset({"'s",
#             '161',
#             '199',
#             'channel',
#             'going',
#             'oscar',
#             'pistorius',
#             'rockville',
#             'trial'}),
#  '5b17172fda870923dcb0ef6a': frozenset({"'s",
#             'case',
#             'like',
#             'much',
#             'murdered',
#             'oscar',
#             'people',
#             'pistorius',
#             'publicized',
#             'reeva',
#             'remind',
#             'thanks',
#             'woman',
#             'would',
#             'young'}),
#  '5b17172fda870923dcb0ef95': frozenset({"'s",
#             'coverage',
#             'enjoy',
#             'mainstream',
#             'media',
#             'oscar',
#             'oscars',
#             'pistorius',
#             'starts',
#             'tomorrow',
#             'tonight',
#             'trial',
#             'ukraine'}),
#  '5b17172fda870923dcb0ef99': frozenset({"'s",
#             'begins',
#             'end',
#             'family',
#             'frenzy',
#             'guardian',
#             'media',
#             'oscar',
#             'pistorius',
#             'plead',
#             'trial'}),
#  '5b17172fda870923dcb0efa5': frozenset({"'s",
#             'africa',
#             'amputee',
#             'favorite',
#             'mistake',
#             'murder',
#             'one',
#             'oscar',
#             'pistor',
#             'pistorius',
#             'sons',
#             'south',
#             'star',
#             'track',
#             'trial'}),
#  '5b17172fda870923dcb0efaa': frozenset({"'s",
#             'blade',
#             'girlfriend',
#             'live',
#             'murder',
#             'oscar',
#             'pistorius',
#             'runner',
#             'trial',
#             'tried',
#             'updates'}),
#  '5b17172fda870923dcb0efb4': frozenset({'#yorkyrd',
#             "'s",
#             'africa',
#             'amputee',
#             'favorite',
#             'mistake',
#             'murder',
#             'one',
#             'pistorius',
#             'sons',
#             'south',
#             'trial'}),
#  '5b17172fda870923dcb0efb6': frozenset({'#morenopretty',
#             "'s",
#             'africa',
#             'favorite',
#             'mistake',
#             'murder',
#             'one',
#             'pistorius',
#             'south',
#             'trial'}),
#  '5b17172fda870923dcb0efb8': frozenset({"'s",
#             'blade',
#             'girlfriend',
#             'goes',
#             'murder',
#             'oscar',
#             'pistorius',
#             'runner',
#             'trial'}),
#  '5b17172fda870923dcb0efba': frozenset({"'s",
#             'africa',
#             'amp',
#             'favorite',
#             'mistake',
#             'murder',
#             'one',
#             'pistorius',
#             'sons',
#             'south',
#             'trial'}),
#  '5b17172fda870923dcb0efc0': frozenset({'#teampapucho',
#             "'s",
#             'africa',
#             'amput',
#             'favorite',
#             'mistake',
#             'murder',
#             'one',
#             'pistorius',
#             'sons',
#             'south',
#             'trial'}),
#  '5b17172fda870923dcb0efc6': frozenset({"'s",
#             'africa',
#             'argue',
#             'bringing',
#             'crime',
#             'fear',
#             'high',
#             'murder',
#             'oscar',
#             'pistorius',
#             'rate',
#             'south',
#             'trial'}),
#  '5b17172fda870923dcb0efd6': frozenset({"'s",
#             'africa',
#             'awaiting',
#             'begin',
#             'correspondent',
#             'court',
#             'follow',
#             'good',
#             'murder',
#             'oscar',
#             'pistorius',
#             'south',
#             'time',
#             'trial'}),
#  '5b17172fda870923dcb0efda': frozenset({'#9newsat6',
#             "'s",
#             'girlfriend',
#             'go',
#             'live',
#             'murder',
#             'olympian',
#             'oscar',
#             'pistorius',
#             'prepares',
#             'trial'}),
# ...
#             '2014',
#             'feed',
#             'happening',
#             'link',
#             'live',
#             'march',
#             'murder',
#             'oscar',
#             'pistorius',
#             'right',
#             'trial'}),
#  '5b171732da870923dcb1300e': frozenset({'#craz',
#             "'ve",
#             '3',
#             'already',
#             'amp',
#             'burger',
#             'fucking',
#             'heard',
#             'idiot',
#             'michell',
#             'oscar',
#             'pistorius',
#             'right',
#             'trial',
#             'truth',
#             'versions',
#             'watching'}),
#  '5b171732da870923dcb13022': frozenset({"'s",
#             'bit',
#             'idina',
#             'important',
#             'john',
#             'little',
#             'murder',
#             'oscar',
#             'pistorius',
#             'poor',
#             'saying',
#             'started',
#             'travolta',
#             'trial'}),
#  '5b171732da870923dcb1302c': frozenset({'back',
#             'edge',
#             'money',
#             'murder',
#             'oscar',
#             'paddy',
#             'pistorius',
#             'right',
#             'seen',
#             'trial',
#             'walks'}),
#  '5b171732da870923dcb1303f': frozenset({"'re",
#             '107',
#             '2',
#             '24hr',
#             'amp',
#             'begin',
#             'cove',
#             'day',
#             'giving',
#             'least',
#             'may',
#             'media',
#             'oscar',
#             'pistorius',
#             'promoting',
#             'regret',
#             'testimony',
#             'think',
#             'trial',
#             'witness'}),
#  '5b171732da870923dcb1306f': frozenset({"'s",
#             'african',
#             'athlete',
#             'heard',
#             'lawyers',
#             'murder',
#             'neighbour',
#             'oscar',
#             'pistorius',
#             'question',
#             'scream',
#             'south',
#             'terrible',
#             'told',
#             'trial',
#             'woman'}),
#  '5b171732da870923dcb13075': frozenset({'amp',
#             'ba',
#             'botswana',
#             'cops',
#             'day',
#             'investigate',
#             'mmolaile',
#             'nkabo',
#             'oscar',
#             'pistorius'}),
#  '5b171732da870923dcb13077': frozenset({'amp',
#             'ba',
#             'banna',
#             'botswana',
#             'cops',
#             'day',
#             'investigate',
#             'later',
#             'lmao',
#             'lmfao',
#             'mmolaile',
#             'nkabo',
#             'oscar',
#             'pistorius'}),
#  '5b171732da870923dcb13080': frozenset({"'s",
#             'eh',
#             'getting',
#             'money',
#             'oscar',
#             'pistorius',
#             'worth'}),
#  '5b171732da870923dcb1308e': frozenset({'#barackobama',
#             'african',
#             'another',
#             'event',
#             'get',
#             'oscar',
#             'oscarpistorius',
#             'pistorius',
#             'south',
#             'trial'}),
#  '5b171732da870923dcb130aa': frozenset({"'s",
#             'better',
#             'justice',
#             'murder',
#             'oscar',
#             'performing',
#             'pistorius',
#             'put',
#             'reeva',
#             'sa',
#             'spotlight',
#             'steenkamp',
#             'system',
#             'trial',
#             'usual'}),
#  '5b171732da870923dcb130ba': frozenset({"'s",
#             'convicted',
#             'even',
#             'go',
#             'got',
#             'innocent',
#             'love',
#             'minds',
#             'murder',
#             'oscar',
#             'people',
#             'pistorius',
#             'small',
#             'though',
#             'time',
#             'want'}),
#  '5b171732da870923dcb130cf': frozenset({'#pistorius',
#             'another',
#             'court',
#             'followed',
#             'happened',
#             'home',
#             'lupita',
#             'night',
#             'one',
#             'oscar',
#             'really'}),
#  '5b171732da870923dcb13109': frozenset({'#pistorius',
#             "'s",
#             'adjournment',
#             'lawyers',
#             'oscar',
#             'reassuring',
#             'seem'}),
#  '5b171732da870923dcb1312b': frozenset({'amp',
#             'ba',
#             'botswana',
#             'cops',
#             'day',
#             'hayibo',
#             'investigate',
#             'later',
#             'lol',
#             'mmolaile',
#             'nkabo',
#             'oscar',
#             'pistorius',
#             'rt',
#             'sibs'}),
#  '5b171732da870923dcb13136': frozenset({"'s",
#             '2',
#             'day',
#             'gt;oscar',
#             'gt;reeva',
#             'here&gt',
#             'judge',
#             'media',
#             'news',
#             'questioned&gt',
#             'screams',
#             'warns'}),
#  '5b171732da870923dcb13162': frozenset({'#korea',
#             "'s",
#             'accused',
#             'anger',
#             'identified',
#             'judge',
#             'news',
#             'oscar',
#             'pistorius',
#             'trial',
#             'witness'}),
#  '5b171732da870923dcb13168': frozenset({"'s",
#             '/r',
#             'feed',
#             'happening',
#             'inside',
#             'link',
#             'live',
#             'murder',
#             'oscar',
#             'pistorius',
#             'right',
#             'trial',
#             'via',
#             'worldnews'}),
#  '5b171732da870923dcb1317f': frozenset({'#sp4zee',
#             'accoun',
#             'conflict',
#             'oscar',
#             'pistorius',
#             'says',
#             'statement',
#             'testimony',
#             'witness'}),
#  '5b171732da870923dcb13181': frozenset({"'s",
#             'africa',
#             'dennis',
#             'denuto',
#             'handing',
#             'keeps',
#             'lawyers',
#             'lol',
#             'notes',
#             'oscar',
#             'pistorius',
#             'scribbling',
#             'south'}),
#  '5b171732da870923dcb13189': frozenset({'#breaking',
#             'acc',
#             'conflict',
#             'oscar',
#             'pistorius',
#             'says',
#             'statement',
#             'testimony',
#             'witness'}),
#  '5b171732da870923dcb1318d': frozenset({'#breakingnews',
#             'account',
#             'changed',
#             'conflict',
#             'oscar',
#             'pistorius',
#             'says',
#             'statement',
#             'testimony',
#             'witness'}),
#  '5b171732da870923dcb1319a': frozenset({'#savaus',
#             "'s",
#             'girl',
#             'oscar',
#             'pistorius',
#             'shoot',
#             'would'}),
#  '5b171732da870923dcb131c8': frozenset({'bloodcurdling',
#             'heard',
#             'independent',
#             'oscar',
#             'pistorius',
#             'says',
#             'screams',
#             'trial',
#             'witness'}),
#  '5b171732da870923dcb131ce': frozenset({'amp',
#             'case',
#             'high',
#             'intimidation',
#             'like',
#             'media',
#             'much',
#             'oscar',
#             'pistorius',
#             'potential',
#             'prejudice',
#             'profile',
#             'stir',
#             'televise',
#             'unwise'}),
#  '5b171732da870923dcb131fa': frozenset({'court',
#             'image',
#             'order',
#             'prosecutor',
#             'says',
#             'shown',
#             'testifying',
#             'witness'}),
#  '5b171732da870923dcb1323a': frozenset({"'s",
#             '2nd',
#             'day',
#             'interrupte',
#             'interrupted',
#             'murder',
#             'oscar',
#             'pistorius',
#             'second',
#             'trial'}),
#  '5b171732da870923dcb13246': frozenset({'#pistorius',
#             'back',
#             'bet',
#             'found',
#             'guilty',
#             'money',
#             'oscar',
#             'pistorius',
#             'right',
#             'rt'}),
#  '5b171732da870923dcb13257': frozenset({"'s",
#             'chat',
#             'count',
#             'friendly',
#             'girls',
#             'join',
#             'nigeria',
#             'oscar',
#             'pistorius',
#             'trial'}),
#  '5b171732da870923dcb13260': frozenset({"'s",
#             'deserve',
#             'deserves',
#             'girlfriend',
#             'hung',
#             'killed',
#             'live',
#             'murder',
#             "n't",
#             'oscar',
#             'pistorius'}),
#  '5b171732da870923dcb13262': frozenset({"'s",
#             'court',
#             'fred',
#             'fuck',
#             'oscar',
#             'pistorius',
#             'today'}),
#  '5b171732da870923dcb13273': frozenset({'amp',
#             'court',
#             'latest',
#             'media',
#             'oscarpistorius',
#             'pic',
#             'pretoria',
#             'published',
#             'trial',
#             'warning',
#             'witness'}),
#  '5b171732da870923dcb132a1': frozenset({'90,000',
#             'amp',
#             'bet',
#             'call',
#             'donate',
#             'offensive',
#             'people',
#             'remove'}),
#  '5b171732da870923dcb132aa': frozenset({'back',
#             'court',
#             'day',
#             'every',
#             'going',
#             'lool',
#             'oscar',
#             'pistorius',
#             'really',
#             'rt',
#             'thing'}),
#  '5b171732da870923dcb132b0': frozenset({"'s",
#             'blade',
#             'case',
#             'court',
#             'day',
#             'enters',
#             'live',
#             'murder',
#             'newslocker',
#             'oscar',
#             'pistorius',
#             'runner',
#             'second',
#             'trial',
#             'updates'}),
#  '5b171732da870923dcb132b7': frozenset({"'s",
#             '1/2',
#             'becomes',
#             'disgusted',
#             'killer',
#             'murder',
#             'official',
#             'sport',
#             'trial',
#             'trivialised',
#             'woman'}),
#  '5b171732da870923dcb132b9': frozenset({"'ll",
#             'back',
#             'door',
#             'emotion',
#             'hear',
#             'increased',
#             'invite',
#             "n't",
#             'oscar',
#             'pistorius',
#             'put',
#             'roux',
#             'scream',
#             'state',
#             'test',
#             'toilet',
#             'trial',
#             'wo'}),
#  '5b171732da870923dcb132c2': frozenset({'denies',
#             'emptying',
#             'fully',
#             'gun',
#             'loaded',
#             'midnight',
#             'murder',
#             'oscar',
#             'pistorius',
#             'poo',
#             'whilst'}),
#  '5b171732da870923dcb132c8': frozenset({'#pistorius',
#             "'s",
#             'ff',
#             'friday',
#             'oscar',
#             'pistorius',
#             'trial',
#             'tweeting'}),
#  '5b171732da870923dcb132ca': frozenset({"'s",
#             'crowded',
#             'going',
#             'made',
#             'markers',
#             'oscar',
#             'paperwork',
#             'pistorius',
#             'round',
#             'team',
#             'though'}),
#  '5b171732da870923dcb132d6': frozenset({"'s",
#             'amp',
#             'betting',
#             'charity',
#             'donate',
#             'offensive',
#             'oscar',
#             'paddy',
#             'pistorius',
#             'power',
#             'profits',
#             'stop',
#             'trial',
#             'women'}),
#  '5b171732da870923dcb132da': frozenset({"'s",
#             'bet',
#             'paddy',
#             'power',
#             'sick',
#             'via'}),
#  '5b171732da870923dcb132f8': frozenset({'eyes',
#             'fact',
#             'look',
#             'mother',
#             'oscar',
#             'pistorius',
#             'reeva',
#             'refused',
#             'says',
#             'steenkamps',
#             'turn'}),
#  '5b171732da870923dcb13305': frozenset({'#breaking',
#             'conflict',
#             'news',
#             'oscar',
#             'pistorius',
#             'says',
#             'statement',
#             'testimony',
#             'witness'}),
#  '5b171732da870923dcb1332d': frozenset({'177',
#             'away',
#             'blows',
#             'defense',
#             'door',
#             'heard',
#             'hole',
#             'locked',
#             'oscar',
#             'petrifying',
#             'pistorius',
#             'says',
#             'screams',
#             'shots',
#             'trial'}),
#  '5b171732da870923dcb13363': frozenset({"'s",
#             'believe',
#             'car',
#             'case',
#             'guilty',
#             'hmmmm',
#             'nobody',
#             'nt',
#             'oscar',
#             'personally',
#             'pistorius',
#             'tricky',
#             'u'}),
#  '5b171732da870923dcb13374': frozenset({"'s",
#             'ba',
#             'bathong',
#             'fair',
#             'free',
#             'go',
#             'jub',
#             'lekhoa',
#             'let',
#             'modimo',
#             'must',
#             'oscar',
#             'pistorius',
#             'prison',
#             'therefore'}),
#  '5b171732da870923dcb13378': frozenset({'back',
#             'bet',
#             'found',
#             'money',
#             'right',
#             'rt'}),
#  '5b171732da870923dcb13399': frozenset({"'s",
#             'allegedly',
#             'face',
#             'interrupted',
#             'oscar',
#             'pistorius',
#             'shown',
#             'trial',
#             'witness'}),
#  '5b171732da870923dcb133a1': frozenset({'#enca',
#             "'s",
#             '2',
#             'african',
#             'bid',
#             'extradited',
#             'failing',
#             'judiciary',
#             'live',
#             'making',
#             'sa',
#             'south',
#             'system',
#             'trial'}),
#  '5b171732da870923dcb133a6': frozenset({"'s",
#             'breach',
#             'day',
#             'hits',
#             'interrupted',
#             'murder',
#             'oscar',
#             'pistorius',
#             'privacy',
#             'second',
#             'today',
#             'trial'}),
#  '5b171732da870923dcb133a8': frozenset({'#southafrica',
#             "'ll",
#             "'s",
#             'already',
#             'dating',
#             'disgusts',
#             'famous',
#             'found',
#             'guilty',
#             'oscar',
#             'oscartrial',
#             'pistorius',
#             'probably',
#             'unfortunately'}),
#  '5b171732da870923dcb133ad': frozenset({"'s",
#             'absolute',
#             'betting',
#             'outcome',
#             'paddy',
#             'petition',
#             'please',
#             'power',
#             'sign',
#             'stop',
#             'woman',
#             'young'}),
#  '5b171732da870923dcb133bf': frozenset({'#oscartrial',
#             "'s",
#             'adjourned',
#             'court',
#             'currently',
#             'follow',
#             'happening',
#             'know',
#             'livestream',
#             'oscar',
#             'pistorius',
#             'trial'}),
#  '5b171732da870923dcb133d5': frozenset({'#pistorius',
#             "'s",
#             'already',
#             'amp',
#             'break',
#             'ca',
#             'day',
#             'give',
#             "n't",
#             'oscar',
#             'please',
#             'second',
#             'take',
#             'trial',
#             'us'}),
#  '5b171732da870923dcb133db': frozenset({'amp',
#             'beautiful',
#             'oscar',
#             'pistorius',
#             'stay',
#             'trial',
#             'tv',
#             'watch',
#             'weather'}),
#  '5b171732da870923dcb133f2': frozenset({"'s",
#             '2nd',
#             'day',
#             'interrupted',
#             'murder',
#             'oscar',
#             'pistorius',
#             'second',
#             'trial'}),
#  ...}

# %%
files = list(data_path.glob('event_*-topic_*-tweet_ids_sorted_mmr.txt'))

all_tweets = get_tweets()
all_tweets_d = dict()
for t in all_tweets:
    all_tweets_d[str(t['_id'])] = t

    
for f_0 in files:
    _, ev, top, _, _, _ = f_0.name.split("_")
    event_id = ev.split("-")[0]
    topic_id = top.split("-")[0]
    
    with f_0.open() as f:
        for i, line in enumerate(f):
            r_id = line[:-1]
            tweet = all_tweets_d[r_id]
            print(tweet['text'])
            
            if i == 10:
                break
                
        print()
        print()
# Out:
# Homes and offices collapse as massive earthquake rocks Nepal destroying historic 19th-century tower : At least... http://t.co/Zn7jsueOUD
# ZH: Hundreds Dead After Devastating Nepal Earthquake Topples Structures, Starts Avalanches: A little over four... http://t.co/5E1nJl9Zy1
# More than 1,300 dead after devastating earthquake: Nepals worst earthquake in 81 years has toppled structures... http://t.co/3tPIwBoMME
# Earthquake kills more than 800 in Nepal. turns two historic Kathmandu landmarks into rubble
# A man is freed from the rubble of a destroyed building in Katmandu. Earthquake kills hundreds http://t.co/av00lYkQY5 http://t.co/8lSWSXmYf6
# More than 900 killed after the 7.8 magnitude earthquake in Nepal. Historical sites were devastated. Let's send our prayers for them
# #earthquake  Media reports from Nepal say that historical tower #Dharahara (similar to Delhis #Qutb Minar) in... http://t.co/AP5h2wwe48
# Deadly! Destructive 7.9 EARTHQUAKE Shakes NEPAL; 600+ Dead!; Historical Blds. Dstryd: Chaotic scene http://t.co/Z8BiE0HUZo
# BERNAMA - Nepal Quake: High Death Toll, Devastating Damage To Historical Sites http://t.co/77vJ7sW67A
# More than 100 people are known to have died in a powerful earthquake that struck Nepal, wrecking many historic... http://t.co/5ROmcMX4J0
# So many lives lost historic monuments damaged really really sad :(:(#Earthquake#Nepal #Kathmandu
#
#
# Some more peace loving Muslims have taken hostages at #Corinthia hotel in #Tripoli #Libya \nWe can only hope everyone is rescued soon
# Libyan security official says gunmen at luxury Tripoli hotel take hostages; 3 guards killed.: Gunmen stormed a... http://t.co/6kV22g3zyo
# Oscar Pistorius is clearly innocent. Anyone who blindly shoots into the toilet should be set free.
# OMG! I can't believe Pistorius breaks down as trial hears grisly details of killing http://t.co/GgKOrDBhBA
# Day 20 of Oscar Pistorius's trial.. Please just lock him up and throw away the key!  His so called stories clearly don't add up.
# First Tiger Woods, then Lance Armstrong, and now Oscar Pistorius.\nI think Nike should start telling their athletes "Don't Do It"
# I still can't believe they're not using a jury in this Oscar Pistol 'Pete' Pistorius trial.. It's a madness that 1 person makes the decision
# I wonder if oscar pistorius will still hav a spring in his step if hes found guilty of murder!
# This Oscar Pistorius trial is as weird as the Shiren Dewani case. I don't know what to believe really happened. But the courts will decide.
#
#
# Terrorist attack underway in Tripoli, Libya. A car bomb went off at a hotel which was then stormed by gunmen. Hostages now held. #KSATnews
# Tripoli: 5 Masked Armed Gunmen stormed and attacked A Luxury Hotel,Car Bomb also Explodes, Eight reported killed- http://t.co/4qFAuPCLma
# BREAKING NEWS: TERRORIST ATTACK UPSCALE HOTEL IN TRIPOLI, LIBYA  #theblaze Get TheBlaze TheBlaze Radio Network... http://t.co/CSIANYcFbt
# #CorinthiaHotel Suicide bombers &amp; 5 masked gunmen attack hotel, hostages on top floor  #http://on.rt.com/i8dpf7 Lybia
# Global Intelligence Confirms: 12 More Injured When #Militants Attacked #Tripoli Hotel, Libya.
# @AP: BREAKING: Employee says 5 gunmen attack luxury Libyan hotel popular with foreigners; 1 guard killed. Terrorist act targeting who
# #TeamFollowBack #FF Militant attack top Libya hotel: Gunmen possibly linked to Islamic Stat... http://t.co/6C2K4Ub2kB #InstantFollowBack
# BREAKING NEWS At least 8 dead in terror attack on Libya hotel    via @FoxNews http://t.co/GJiWXUZKqQ
# Another terror attack! @timesofindia: Gunmen at Libyan luxury hotel take hostages; 3 guards dead - #worldnews via http://t.co/AsLbOelUNl
# Hostages held by gunmen at #Tripoli hotel, 3 guards killed in attack http://t.co/fSML4uRIR6 #Libya http://t.co/2W2UHS0YaF
# RT cnnbrk "Gunmen attack luxurious Corinthia Hotel in Tripoli; not immediately clear if there are casualties. http://t.co/TKpBK04rS9"

# %%
files = list(data_path.glob('event_*-topic_*-tweet_ids_sorted_mmr.txt'))

all_tweets = get_tweets()
all_tweets_d = dict()
for t in all_tweets:
    all_tweets_d[str(t['_id'])] = t

    
for f_0 in files:
    _, ev, top, _, _, _ = f_0.name.split("_")
    event_id = ev.split("-")[0]
    topic_id = top.split("-")[0]
    
    with f_0.open() as f:
        for i, line in enumerate(f):
            r_id = line[:-1]
            tweet = all_tweets_d[r_id]
            print(tweet['text'])
            
            if i == 10:
                break
                
        print()
        print()
# Out:
# 2018-07-06 15:54:26,139 : getting all tweets
# Homes and offices collapse as massive earthquake rocks Nepal destroying historic 19th-century tower : At least... http://t.co/Zn7jsueOUD
# ZH: Hundreds Dead After Devastating Nepal Earthquake Topples Structures, Starts Avalanches: A little over four... http://t.co/5E1nJl9Zy1
# More than 1,300 dead after devastating earthquake: Nepals worst earthquake in 81 years has toppled structures... http://t.co/3tPIwBoMME
# Earthquake kills more than 800 in Nepal. turns two historic Kathmandu landmarks into rubble
